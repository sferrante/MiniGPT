# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch import nn
import torch.nn.functional as F
from tqdm import tqdm
import time
import re
from collections import Counter
import math

from TransformerModel import *
from utils import *

# %% [markdown]
# # Data Collection

# %%
### ~~~~~~~~~~~~~~~~~~~~~ ###
###    token definition   ###
### ~~~~~~~~~~~~~~~~~~~~~ ###
paths = ["data/PrideAndPrejudice.txt", "data/Emma.txt", "data/SenseAndSensibility.txt"]
text = "\n".join(open(p, "r", encoding="utf-8", errors="ignore").read().lower() for p in paths)

# simple tokenizer: words or single punctuation marks
tokens = re.findall(r"[a-z]+|[0-9]+|[^\s\w]", text)
print("num tokens:", len(tokens), "unique:", len(set(tokens)))
# Out:
# num tokens: 314744 unique: 9376

# %%
### ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ###
###    vocab definition, encoding   ###
### ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ###
vocab_size = 10_000
special = ["<pad>", "<unk>"]  # pad will make each token same length, unk is reserved for words not in vocab

counts = Counter(tokens)
most_common = [w for (w, _) in counts.most_common(vocab_size - len(special))]
vocab = special + most_common

# string-to-index,  index-to-string
stoi = {w:i for i,w in enumerate(vocab)}
itos = {i:w for w,i in stoi.items()}

# ids = entire book written in integers
ids = torch.tensor([stoi.get(tok, stoi["<unk>"]) for tok in tokens], dtype=torch.long)
print("ids shape:", ids.shape, "UNK rate:", (ids == stoi["<unk>"]).float().mean().item())
# Out:
# ids shape: torch.Size([314744]) UNK rate: 0.0

# %%
print(ids[:10])
# Out:
# tensor([4073,    4,  145,  137,  771,    6,  404,    7,  874,   46])

# %%
### ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ###
###    Sentence / Phrase Extractor   ###
### ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ###
# batch_size = number of excerpts
# block_size = length of each excerpt
def get_batch(data_ids, batch_size=32, block_size=128, device="cpu"):
    # random starting indices
    ix = torch.randint(0, len(data_ids) - block_size - 1, (batch_size,))
    x = torch.stack([data_ids[i:i+block_size] for i in ix]).to(device)  ## random sentence / phrase
    y = torch.stack([data_ids[i+1:i+block_size+1] for i in ix]).to(device) ## shifted sentence / phrase
    return x, y

# quick sanity check
x, y = get_batch(ids, batch_size=4, block_size=8)
print(x)
print(x[0].tolist())
print(y[0].tolist())
print([itos[i] for i in x[0].tolist()])
print([itos[i] for i in y[0].tolist()])
# Out:
# tensor([[   6,  419,  353,  435,    2,   14,   12, 1734],
#         [1167,    3,   38,   18,  615,    5,   21,  219],
#         [   7,   40,   88,  345,  463,    6,   39,  225],
#         [  28,    5,  105,   95,    6,   58,  210,    2]])
# [6, 419, 353, 435, 2, 14, 12, 1734]
# [419, 353, 435, 2, 14, 12, 1734, 2]
# ['of', 'four', 'years', 'old', ',', 'it', 'was', 'secured']
# ['four', 'years', 'old', ',', 'it', 'was', 'secured', ',']

# %% [markdown]
# # Model Definition & Training

# %%
##  See TransformerModel.py for  
##    -- CausalSelfAttention
##    -- Block = LayerNorm + SelfAtt + LayerNorm + MLP 
##    -- TinyGPT

# %%
B, T, d_model, n_heads = 1, 5, 64, 4
x = torch.randn(B, T, d_model)

attn = CausalSelfAttention(d_model=d_model, n_heads=n_heads, block_size=128);
y1 = attn(x)

# %%
### ~~~~~~~~~~~~~~~~~~~~ ###
###    Model Definition  ###
### ~~~~~~~~~~~~~~~~~~~~ ###
device = "cpu"
# hyperparams
block_size = 128  ## excerpt size (few sentences)
batch_size = 32   ## number of excerpts

model = TinyGPT(vocab_size=len(vocab), block_size=block_size, 
                d_model=128, n_blocks=4, n_heads=4, d_ff=512).to(device)

n_params = sum(p.numel() for p in model.parameters())
n_trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
print("total params:", n_params)
print("trainable params:", n_trainable)

# optimizer
lr = 3e-4
opt = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=0.1)
# Out:
# total params: 2008064
# trainable params: 2008064

# %%
### ~~~~~~~~~~~~~~~ ###
###    Train Model  ###
### ~~~~~~~~~~~~~~~ ###
def decode(token_ids):
    return " ".join(itos[i] for i in token_ids)


steps = 100_000; 
losses = []; 
for step in range(1, steps+1):
    ## Get a random excerpt (x) and excerpt+1 (y) 
    x, y = get_batch(ids, batch_size=batch_size, block_size=block_size, device=device)  # (B,T)
    logits = model(x)  # (B,T,V)
    loss = F.cross_entropy(logits.view(-1, len(vocab)), y.view(-1))

    opt.zero_grad()
    loss.backward()
    torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
    opt.step()
    if step % 200 == 0:
        losses.append(loss.item())
        print("step", step, "loss", float(loss))
        # quick greedy sample from last position
        ctx, _ = get_batch(ids, batch_size=1, block_size=15, device=device)
        with torch.no_grad():
            out = ctx.clone()
            for _ in range(15):
                logits = model(out[:, -block_size:])
                next_id = logits[:, -1, :].argmax(dim=-1, keepdim=True)  # choose most likely next token
                out = torch.cat([out, next_id], dim=1)
        prompt_ids = out[0, :15].tolist()
        gen_ids    = out[0, 15:30].tolist()
        print("     Real Excerpt:\n", decode(prompt_ids))
        print("Generated Excerpt:\n", decode(gen_ids))
        print()
# Out:
# step 200 loss 10.467161178588867
#      Real Excerpt:
#  the season was fine , and from first seeing the place under the advantage of
# Generated Excerpt:
#  the , and , and , and , and , and , and , and
#
# step 400 loss 7.2160773277282715
#      Real Excerpt:
#  with him . he is not a young man with whom one can be intimately
# Generated Excerpt:
#  , and , and the , and , and , and , and , and
#
# step 600 loss 6.134617805480957
#      Real Excerpt:
#  have never seen before . i cannot catch their tone of conversation , or appear
# Generated Excerpt:
#  . i am , and i am not be , and i am sure i
#
# step 800 loss 5.944627285003662
#      Real Excerpt:
#  and soon afterwards got up and walked about the room . her figure was elegant
# Generated Excerpt:
#  , and , and the same , and , and her , and the ,
#
# step 1000 loss 5.6505513191223145
#      Real Excerpt:
#  to the exclusion of all conversation , and was too much engrossed by his own
# Generated Excerpt:
#  , and , and the , and the , and the , and the ,
#
# step 1200 loss 5.598711967468262
#      Real Excerpt:
#  like mr . collins himself , has been charged with exaggeration . there is ,
# Generated Excerpt:
#  and the to the , and the to the of the whole of the ,
#
# step 1400 loss 5.440643787384033
#      Real Excerpt:
#  the end of all his friend ’ s anxious circumspection ! of all his sister
# Generated Excerpt:
#  , and , and , and , and , and the very much , and
#
# step 1600 loss 5.377880096435547
#      Real Excerpt:
#  , i believe , sir . ” “ yes , indeed , and received no
# Generated Excerpt:
#  , and i have been , i am sure i should not be so much
#
# step 1800 loss 5.241748809814453
#      Real Excerpt:
#  determined ; nor did sir william at all shake her purpose by his attempt at
# Generated Excerpt:
#  the world , and the most had been a very much of the room ,
#
# step 2000 loss 5.064723491668701
#      Real Excerpt:
#  of a sleepless night . mrs . dashwood , too happy to be comfortable ,
# Generated Excerpt:
#  and the first , and the room , and the room , and the very
#
# step 2200 loss 5.196926116943359
#      Real Excerpt:
#  you , had they been indifferent , or had they even been favourable , do
# Generated Excerpt:
#  not be in the world . ” “ i have been so much to be
#
# step 2400 loss 5.10611629486084
#      Real Excerpt:
#  t they ? " but then again , the dread of having been too civil
# Generated Excerpt:
#  , " " " said she is , " said marianne , " said elinor
#
# step 2600 loss 5.170419692993164
#      Real Excerpt:
#  , she paid no credit . that he was really fond of jane , she
# Generated Excerpt:
#  had been in the whole of the whole of the house , and the whole
#
# step 2800 loss 5.058094024658203
#      Real Excerpt:
#  she finished it . “ is it not clear enough ? does it not expressly
# Generated Excerpt:
#  to be so much . ” “ i am sure you . ” “ i
#
# step 3000 loss 5.065031051635742
#      Real Excerpt:
#  can bestow . ” miss bingley immediately fixed her eyes on his face , and
# Generated Excerpt:
#  his own , and his own , and his own , and his own ,
#
# step 3200 loss 4.960725784301758
#      Real Excerpt:
#  decrease of a promising young brood , she found fresh sources of merriment . the
# Generated Excerpt:
#  whole of the whole of the house , and the house , and the time
#
# step 3400 loss 4.78350830078125
#      Real Excerpt:
#  demeanor , and a general want of understanding . the same manners , however ,
# Generated Excerpt:
#  in the house , and the room , and the room , and the world
#
# step 3600 loss 4.870037078857422
#      Real Excerpt:
#  marianne ' s note , by assuring me that i was still as dear to
# Generated Excerpt:
#  be in the room . " " " " said elinor , " said elinor
#
# step 3800 loss 4.7986979484558105
#      Real Excerpt:
#  for the fun of having another band - box ! well , now let us
# Generated Excerpt:
#  , and i am sure , i am sure , i am sure , and
#
# step 4000 loss 4.649654388427734
#      Real Excerpt:
#  their actions , - - may be rendered ridiculous by a person whose first object
# Generated Excerpt:
#  of the world . ” “ i am sure i am sure i am sure
#
# step 4200 loss 4.699621677398682
#      Real Excerpt:
#  i knew i should persuade you at last . i was sure you loved your
# Generated Excerpt:
#  sister . ” “ i am sure , ” said he , “ i am
#
# step 4400 loss 4.619967937469482
#      Real Excerpt:
#  nothing but a persuasion of my being indifferent would have prevented his coming down again
# Generated Excerpt:
#  . i am sure i am not know what i am sure i am sure
#
# step 4600 loss 4.559103012084961
#      Real Excerpt:
#  much to be talked of , in marrying her ; and the good - natured
# Generated Excerpt:
#  , she was not the most longer , and the house , and the house
#
# step 4800 loss 4.5970234870910645
#      Real Excerpt:
#  only a letter of business ? come , come , this won ' t do
# Generated Excerpt:
#  you , and i am sure , that i am sure , as i am
#
# step 5000 loss 4.5192131996154785
#      Real Excerpt:
#  ' t think how disappointed he will be if you don ' t come to
# Generated Excerpt:
#  be in the world . " " " " i have been a very good
#
# step 5200 loss 4.595967769622803
#      Real Excerpt:
#  bingley , which might only grieve her sister further . [ illustration : “ how
# Generated Excerpt:
#  i have been very well , ” said she , “ i am sure i
#
# step 5400 loss 4.395212650299072
#      Real Excerpt:
#  supposed of you , ” said elizabeth . “ you begin to comprehend me ,
# Generated Excerpt:
#  ” said he , “ i am sure it is a very much . i
#
# step 5600 loss 4.458428859710693
#      Real Excerpt:
#  he might see the ring , and then i bowed and smiled like anything .
# Generated Excerpt:
#  ” “ i am sure i am sure i am sure i am sure i
#
# step 5800 loss 4.281609058380127
#      Real Excerpt:
#  without wide spread public support and donations to carry out its mission of increasing the
# Generated Excerpt:
#  house , and the house , and the house , and the house , and
#
# step 6000 loss 4.424483776092529
#      Real Excerpt:
#  heading to chapter lvi . 431 “ after a short survey ” 434 “ but
# Generated Excerpt:
#  i am not a few can be so much to be so much to be
#
# step 6200 loss 4.447478771209717
#      Real Excerpt:
#  manner in which her time had passed at hunsford , she mentioned colonel fitzwilliam ’
# Generated Excerpt:
#  s , and she was not to be able to be the same time .
#
# step 6400 loss 4.177852153778076
#      Real Excerpt:
#  added pain to many a painful hour ; but one evening , mrs . dashwood
# Generated Excerpt:
#  , and her sister , who had been so much in her , and she
#
# step 6600 loss 4.35317850112915
#      Real Excerpt:
#  , and as we could not live without one another , we are just returned
# Generated Excerpt:
#  to be in the room . " " i am sure i am sure i
#
# step 6800 loss 4.246550559997559
#      Real Excerpt:
#  we always know when we are acting wrong , and with such a conviction i
# Generated Excerpt:
#  am sure you . ” “ i am sure , ” said elizabeth , “
#
# step 7000 loss 4.230472564697266
#      Real Excerpt:
#  on any other object in the room . in one of these excursive glances she
# Generated Excerpt:
#  was a very good - humoured and her own . she was not to be
#
# step 7200 loss 4.134600639343262
#      Real Excerpt:
#  , give it away or re - use it under the terms of the project
# Generated Excerpt:
#  gutenberg license included with this ebook or online at www . gutenberg . org .
#
# step 7400 loss 4.308955669403076
#      Real Excerpt:
#  its taking place in time . a thousand a - year is a great deal
# Generated Excerpt:
#  of a great deal of the world , and the other , i am sure
#
# step 7600 loss 4.264864921569824
#      Real Excerpt:
#  him today ? " but marianne could no more satisfy him as to the colour
# Generated Excerpt:
#  , and she could not be , and she was not to be in the
#
# step 7800 loss 4.0030083656311035
#      Real Excerpt:
#  the furniture , and they happened to be so doatingly fond of children that lady
# Generated Excerpt:
#  middleton ' s . the house was the same , and the house , and
#
# step 8000 loss 3.655832290649414
#      Real Excerpt:
#  ” he added , “ as soon as his marriage was fixed on . and
# Generated Excerpt:
#  his mother , i am sure , i am sure , and i am sure
#
# step 8200 loss 3.792956590652466
#      Real Excerpt:
#  know how mrs . bennet would have stirred the fire ) , when mr .
# Generated Excerpt:
#  gardiner and mrs . gardiner , was not to be the same number of the
#
# step 8400 loss 4.014599800109863
#      Real Excerpt:
#  in again and rest herself . “ she did not choose it , ” said
# Generated Excerpt:
#  she , “ that she is not to be able to be so much as
#
# step 8600 loss 3.8577592372894287
#      Real Excerpt:
#  on her daughters remaining at netherfield till the following tuesday , which would exactly finish
# Generated Excerpt:
#  his wife , and his own , and his own , was not to be
#
# step 8800 loss 3.944465398788452
#      Real Excerpt:
#  , and in spite of its owner having once been within some thousand pounds of
# Generated Excerpt:
#  the present occasion , and the other of the day of the family , and
#
# step 9000 loss 3.8255820274353027
#      Real Excerpt:
#  of us any thing to tell ; you , because you do not communicate ,
# Generated Excerpt:
#  i am sure you will be very much better . " " i am sure
#
# step 9200 loss 3.772451400756836
#      Real Excerpt:
#  once , by your desire . ” “ i am afraid you do not like
# Generated Excerpt:
#  to be so much . ” “ i am not so much to be so
#
# step 9400 loss 3.83182954788208
#      Real Excerpt:
#  ” “ you are severe on us . ” “ it will be her turn
# Generated Excerpt:
#  for him . ” “ i am sure i am sure i am sure i
#
# step 9600 loss 4.013468265533447
#      Real Excerpt:
#  . “ now , ” said she , “ that this first meeting is over
# Generated Excerpt:
#  , i am sure she will be very well . ” “ i am sure
#
# step 9800 loss 3.795886993408203
#      Real Excerpt:
#  must walk to the park , to call on lady middleton . " he engaged
# Generated Excerpt:
#  to his own , " said she , " i have not thought him to
#
# step 10000 loss 3.9066720008850098
#      Real Excerpt:
#  wanting us to visit them these several years ! but i only go for the
# Generated Excerpt:
#  world . " " i have not thought it . " " i have not
#
# step 10200 loss 3.9031460285186768
#      Real Excerpt:
#  elizabeth , angrily ; “ for i have heard you accuse him of nothing worse
# Generated Excerpt:
#  than i have been so much . ” “ i have not the least to
#
# step 10400 loss 3.356013059616089
#      Real Excerpt:
#  arrived for their father , from a different quarter , from mr . collins ;
# Generated Excerpt:
#  and , after a few moments , mr . collins , he was a little
#
# step 10600 loss 3.608901262283325
#      Real Excerpt:
#  s office was a painful one . she was going to remove what she really
# Generated Excerpt:
#  believed to be , and she was not to be in the same . she
#
# step 10800 loss 3.569171905517578
#      Real Excerpt:
#  the lady felt no inclination to trifle with his happiness . the stupidity with which
# Generated Excerpt:
#  had been able to be supposed , and the other , was to be the
#
# step 11000 loss 3.6602249145507812
#      Real Excerpt:
#  , as from the first , believed marianne his real favourite , to make her
# Generated Excerpt:
#  , and her , and her mother ' s , and the other , was
#
# step 11200 loss 3.507208824157715
#      Real Excerpt:
#  agree to the terms of the full project gutenberg ™ license . you must require
# Generated Excerpt:
#  such a user to our found opinions in accordance with the electronic work . 1
#
# step 11400 loss 3.5112898349761963
#      Real Excerpt:
#  of saying too much what he thought on every occasion , without attention to persons
# Generated Excerpt:
#  in the most painful man . but , however , however , as she was
#
# step 11600 loss 3.5567328929901123
#      Real Excerpt:
#  the greatest part of his time there . some mothers might have encouraged the intimacy
# Generated Excerpt:
#  of the day before , and the whole of the day was to be the
#
# step 11800 loss 3.706228017807007
#      Real Excerpt:
#  disrespectfully of any relation of yours , madam . miss lucy steele is , i
# Generated Excerpt:
#  am sure , and i am sure i have not been in the smallest smallest
#
# step 12000 loss 3.552064895629883
#      Real Excerpt:
#  him . ” “ how can you talk so ? ” said jane , faintly
# Generated Excerpt:
#  smiling , “ i have been so much in my power to you ? ”
#
# step 12200 loss 3.418666362762451
#      Real Excerpt:
#  five being thus removed , mrs . bennet sat looking and winking at elizabeth and
# Generated Excerpt:
#  her sister . “ i am sure i am glad you will not be so
#
# step 12400 loss 3.4331865310668945
#      Real Excerpt:
#  - how she should express herself in her note to edward , was now all
# Generated Excerpt:
#  the most agreeable to her . she was not to be so much as to
#
# step 12600 loss 3.43156361579895
#      Real Excerpt:
#  , sir , " said mrs . jennings , " and how did it end
# Generated Excerpt:
#  ? " " i am , " said elinor , " that is very true
#
# step 12800 loss 3.4030652046203613
#      Real Excerpt:
#  , if mrs . ferrars had took a dislike to me . if she had
# Generated Excerpt:
#  been so very much to be so good as to her sister , and so
#
# step 13000 loss 3.4026851654052734
#      Real Excerpt:
#  , and whenever she mentioned her name , it gave a pang to the heart
# Generated Excerpt:
#  of her , and her sister were all the room . she was a great
#
# step 13200 loss 3.311523914337158
#      Real Excerpt:
#  friends . you can ' t think how much i longed to see you !
# Generated Excerpt:
#  " " said she , " i am not . " " i am glad
#
# step 13400 loss 3.3527674674987793
#      Real Excerpt:
#  mother from sending a letter of acquiescence . chapter v no sooner was her answer
# Generated Excerpt:
#  to make her , and her a very good opinion of the world , and
#
# step 13600 loss 3.44623064994812
#      Real Excerpt:
#  better known to me than my own , and i am sure they are dearer
# Generated Excerpt:
#  . " " i am glad you will not be happy , " said mrs
#
# step 13800 loss 3.091677665710449
#      Real Excerpt:
#  lucy , when they parted , gave her a pressing invitation to visit her there
# Generated Excerpt:
#  was a great number of her sister ’ s being in the world , and
#
# step 14000 loss 3.0588345527648926
#      Real Excerpt:
#  they quitted the house , on an excursion through its more immediate premises ; and
# Generated Excerpt:
#  , as she was not a very pretty intermission of the house , she was
#
# step 14200 loss 3.233468532562256
#      Real Excerpt:
#  well as her heart , would have shrunk from such things as the letter from
# Generated Excerpt:
#  his mother , and the two sisters , the two gentlemen saw him , and
#
# step 14400 loss 3.170501232147217
#      Real Excerpt:
#  attempted , to recover her ? ” “ my father has gone to london ,
# Generated Excerpt:
#  ” replied elizabeth , “ i have been so much to do . ” “
#
# step 14600 loss 3.123786211013794
#      Real Excerpt:
#  the constancy of mine as ever , awakened all my remorse . i say awakened
# Generated Excerpt:
#  , and have not the place , and the only lady myself , and i
#
# step 14800 loss 2.9179723262786865
#      Real Excerpt:
#  . [ illustration ] two days after mr . bennet ’ s return , as
# Generated Excerpt:
#  he could be in her , he could not but see how to be .
#
# step 15000 loss 3.0974833965301514
#      Real Excerpt:
#  cases , mr . robert ferrars ( with his excursus in chapter xxxvi . on
# Generated Excerpt:
#  the contrary , however , he heard her , and had been so much to
#
# step 15200 loss 2.9350552558898926
#      Real Excerpt:
#  and spend the evening at rosings . i rather expected , from my knowledge of
# Generated Excerpt:
#  her own family , and i am not to think that i had not been
#
# step 15400 loss 2.991166830062866
#      Real Excerpt:
#  michaelmas , and some of his servants are to be in the house by the
# Generated Excerpt:
#  family . the other , as soon as the world was , it was impossible
#
# step 15600 loss 2.8645200729370117
#      Real Excerpt:
#  with thinking , ” replied jane , “ that he certainly would not marry lydia
# Generated Excerpt:
#  , and i am not so much as to make him . ” “ i
#
# step 15800 loss 2.9524664878845215
#      Real Excerpt:
#  cannot think of it without abhorrence . ” “ we will not quarrel for the
# Generated Excerpt:
#  evening before , ” said elizabeth , as they walked towards the room , “
#
# step 16000 loss 3.1030149459838867
#      Real Excerpt:
#  unconcern with which her praises were received , formed a curious dialogue , and was
# Generated Excerpt:
#  not to be supposed to be the point of a considerable regard , and the
#
# step 16200 loss 2.9087822437286377
#      Real Excerpt:
#  you must visit him as soon as he comes . ” “ i see no
# Generated Excerpt:
#  occasion for your sister , ” said her mother , “ i have not the
#
# step 16400 loss 2.840493679046631
#      Real Excerpt:
#  was not easily overcome . she thanked him with brief , though fervent gratitude ,
# Generated Excerpt:
#  and the other ideas of her sister ' s , and she had always seen
#
# step 16600 loss 2.8104519844055176
#      Real Excerpt:
#  not quite understand the beginning of mrs . jennings ' s speech , neither did
# Generated Excerpt:
#  anything to be at pemberley , she was not in the least agreeable to be
#
# step 16800 loss 2.885953903198242
#      Real Excerpt:
#  ; nothing , therefore , could be fairly conjectured from that , - - though
# Generated Excerpt:
#  not the smallest objection was to be considered . but it was not long ,
#
# step 17000 loss 2.550445795059204
#      Real Excerpt:
#  , like her own mr . bennet , she took an epicurean delight in dissecting
# Generated Excerpt:
#  , and his manners only of his own vanity in the character . he had
#
# step 17200 loss 2.5634210109710693
#      Real Excerpt:
#  be beyond a walk . with a triumphant smile , they were told , that
# Generated Excerpt:
#  every thing was not only one of the world in the world ; but she
#
# step 17400 loss 2.8180649280548096
#      Real Excerpt:
#  contained a sheet of elegant , little , hot - pressed paper , well covered
# Generated Excerpt:
#  with the latter ; and , as she was , she was not sorry that
#
# step 17600 loss 2.809981107711792
#      Real Excerpt:
#  ; and ' setting one ' s cap at a man , ' or '
# Generated Excerpt:
#  ' ' ' says she would have been so much the room . ' the
#
# step 17800 loss 2.6941630840301514
#      Real Excerpt:
#  noisy than pathetic . kitty was the only one who shed tears ; but she
# Generated Excerpt:
#  could not help persevering in the smallest library . the miss dashwoods were now the
#
# step 18000 loss 2.545419454574585
#      Real Excerpt:
#  " " did not you hear him complain of the rheumatism ? and is not
# Generated Excerpt:
#  you to the man , and you might have been able to do it ,
#
# step 18200 loss 2.795517683029175
#      Real Excerpt:
#  of either , and was ever anxious to keep him to herself , and to
# Generated Excerpt:
#  be sure , and to be sure must as soon as they were by the
#
# step 18400 loss 2.755664110183716
#      Real Excerpt:
#  are all rich together . fifty thousand pounds ! and by all accounts , it
# Generated Excerpt:
#  is very hard to be told that you are quite out of the party .
#
# step 18600 loss 2.6052043437957764
#      Real Excerpt:
#  of giving ten guineas to mr . ferrars ! " [ illustration : both gained
# Generated Excerpt:
#  considerable s way . ] " [ illustration : " i have got a shop
#
# step 18800 loss 2.601348638534546
#      Real Excerpt:
#  more , i think , than last year . his attachment to rosings certainly increases
# Generated Excerpt:
#  . " " i have never been more than i know before . " "
#
# step 19000 loss 2.4748053550720215
#      Real Excerpt:
#  and the intelligence of his eye as he spoke , convincing elinor , that whatever
# Generated Excerpt:
#  he had been in the first inferior had been in the course of his own
#
# step 19200 loss 2.4437246322631836
#      Real Excerpt:
#  did not colonel brandon know of sir john ' s proposal to your mother before
# Generated Excerpt:
#  it was . " i do not know , " said she ; " that
#
# step 19400 loss 2.591230869293213
#      Real Excerpt:
#  ” “ indeed ! ” “ yes - - the late mr . darcy bequeathed
# Generated Excerpt:
#  me the dance . he was a man of a man , and i am
#
# step 19600 loss 2.562405586242676
#      Real Excerpt:
#  of sweetness and archness in her manner which made it difficult for her to affront
# Generated Excerpt:
#  anybody , and she was not in spirits , however , to be sure of
#
# step 19800 loss 2.510544776916504
#      Real Excerpt:
#  attending his entrance . anxious and uneasy , the period which passed in the drawing
# Generated Excerpt:
#  - room which he had always made her . she had only the gentleman ,
#
# step 20000 loss 2.5168397426605225
#      Real Excerpt:
#  her , nor in appearing to regard her , but in endeavouring to engage mrs
# Generated Excerpt:
#  . jennings ' s curiosity and elinor was at the end of the gentlemen ,
#
# step 20200 loss 2.3578405380249023
#      Real Excerpt:
#  elizabeth , “ and how much is settled on his side on our sister ,
# Generated Excerpt:
#  i should have been able to do it in a moment . ” “ i
#
# step 20400 loss 2.4577414989471436
#      Real Excerpt:
#  numerous ; but since he had been in the militia , it did not appear
# Generated Excerpt:
#  in the world ; and she was not a very sensible , but she would
#
# step 20600 loss 2.5144150257110596
#      Real Excerpt:
#  was in the ‘ times ’ and the ‘ courier , ’ i know ;
# Generated Excerpt:
#  but that i am very unfortunate , if he is not to be very ill
#
# step 20800 loss 2.3106577396392822
#      Real Excerpt:
#  received no pleasure from anything ; was only impatient to be at home again ,
# Generated Excerpt:
#  and she was not sorry to be the greatest obligations to her mother . she
#
# step 21000 loss 2.4371438026428223
#      Real Excerpt:
#  was written and finished before sense and sensibility - - its original title for several
# Generated Excerpt:
#  times , in such cases as might be , she could not help scruple even
#
# step 21200 loss 2.300147771835327
#      Real Excerpt:
#  bennet followed her , saying , - - “ i am quite sorry , lizzy
# Generated Excerpt:
#  , i do not know what to do . i am now do not know
#
# step 21400 loss 2.3250787258148193
#      Real Excerpt:
#  a few minutes , they were all sent to one of the windows to admire
# Generated Excerpt:
#  them . elinor was obliged to all one of the whole family with her sister
#
# step 21600 loss 2.291611909866333
#      Real Excerpt:
#  ma ' am , " said elinor , " what can you be thinking of
# Generated Excerpt:
#  ? " " i have no doubt of it , " replied elinor , "
#
# step 21800 loss 2.4118340015411377
#      Real Excerpt:
#  wonder what he can be doing there . ” “ perhaps preparing for his marriage
# Generated Excerpt:
#  is if , ” cried jane , “ that it is very true , i
#
# step 22000 loss 2.2565557956695557
#      Real Excerpt:
#  thing were ready for her inhabiting it . they heard her with surprise . mrs
# Generated Excerpt:
#  . palmer joined her with the dining - addition , and they were in silence
#
# step 22200 loss 2.2567360401153564
#      Real Excerpt:
#  pounds was the most remarkable charm of the young lady to whom he was now
# Generated Excerpt:
#  alone , and he could not be more fortunate destructive . she could not bear
#
# step 22400 loss 2.1069486141204834
#      Real Excerpt:
#  " she replied , " ask nothing ; you will soon know all . "
# Generated Excerpt:
#  " i do not know , " replied margaret . " but i have not
#
# step 22600 loss 2.2164926528930664
#      Real Excerpt:
#  by him , to her want of education ; and till her last letter reached
# Generated Excerpt:
#  him his friend , it was a strong attachment to her , she was not
#
# step 22800 loss 2.223079204559326
#      Real Excerpt:
#  no ill - will for being justified in your advice to me last may ,
# Generated Excerpt:
#  and not have the pleasure of any person ’ s head . i was very
#
# step 23000 loss 2.245985746383667
#      Real Excerpt:
#  , she immediately said - - " they are very pretty , ma ' am
# Generated Excerpt:
#  - - she is not a great plan of money . " " oh !
#
# step 23200 loss 2.1778371334075928
#      Real Excerpt:
#  , at that time , in such affliction as rendered her careless of surrounding objects
# Generated Excerpt:
#  . she was very civil , and the pleasure of her own , and when
#
# step 23400 loss 2.0382962226867676
#      Real Excerpt:
#  her , saw her hurry away , and perhaps saw , or even heard ,
# Generated Excerpt:
#  to the rest of the family in the world , and the certain of this
#
# step 23600 loss 2.153508186340332
#      Real Excerpt:
#  to say , " yes , ma ' am . " - - she listened
# Generated Excerpt:
#  to her eyes , with an agitation as well as her sister , with a
#
# step 23800 loss 2.1667072772979736
#      Real Excerpt:
#  - i think she might see us ; and i am sure we would not
# Generated Excerpt:
#  have thought me so very often to - morrow , if you do not ,
#
# step 24000 loss 2.103039026260376
#      Real Excerpt:
#  boys , were to be left under the particular care of their cousin jane ,
# Generated Excerpt:
#  and the other was to be gone to the case with her , and she
#
# step 24200 loss 2.0376594066619873
#      Real Excerpt:
#  have something to tell me of mr . willoughby , that will open his character
# Generated Excerpt:
#  you have not the power of my sister so well as the circumstances were ,
#
# step 24400 loss 2.0309629440307617
#      Real Excerpt:
#  had you a great many smart beaux there ? i suppose you have not so
# Generated Excerpt:
#  much of seeing her . " " i am sure i should have done you
#
# step 24600 loss 2.1457886695861816
#      Real Excerpt:
#  how she , whom the invitation most concerned , felt disposed as to its acceptance
# Generated Excerpt:
#  , and that she had never been to be happy in her way . she
#
# step 24800 loss 1.9995102882385254
#      Real Excerpt:
#  the trademark license , including paying royalties for use of the project gutenberg trademark .
# Generated Excerpt:
#  if you paid the foundation to protect the project gutenberg literary archive foundation , how
#
# step 25000 loss 1.987564206123352
#      Real Excerpt:
#  no avail . duty , affection , every thing was disregarded . i never thought
# Generated Excerpt:
#  it to her . they were again , and when they first came in silence
#
# step 25200 loss 1.9921777248382568
#      Real Excerpt:
#  ebooks in compliance with any particular paper edition . most people start at our website
# Generated Excerpt:
#  which has the main pg search facility : www . gutenberg . org . this
#
# step 25400 loss 2.026195764541626
#      Real Excerpt:
#  him only the saturday before , to make up her pool of quadrille in the
# Generated Excerpt:
#  evening ; and she would not have thought her say of their being together ;
#
# step 25600 loss 2.063201665878296
#      Real Excerpt:
#  were at piquet , and mrs . hurst was observing their game . elizabeth took
# Generated Excerpt:
#  up in the house . their father and the chaise party were with conversation .
#
# step 25800 loss 1.9075177907943726
#      Real Excerpt:
#  her nephew ? ” said she , as she looked in her face . as
# Generated Excerpt:
#  soon as they were out of the room , she added , - - “
#
# step 26000 loss 1.8738588094711304
#      Real Excerpt:
#  , still greater pleasure in bestowing it ; but , upon my word , you
# Generated Excerpt:
#  owe nothing to me - - but i have not believed you . i am
#
# step 26200 loss 1.9988247156143188
#      Real Excerpt:
#  the stranger ’ s air , all wondered who he could be ; and kitty
# Generated Excerpt:
#  and lydia , after complimenting with a call wonderer , engaged in a great front
#
# step 26400 loss 1.9530738592147827
#      Real Excerpt:
#  time without saying a word . elinor , persuaded that he had some communication to
# Generated Excerpt:
#  do some kind of comfort to her sister , though it was in her thoughts
#
# step 26600 loss 1.7994641065597534
#      Real Excerpt:
#  reproach , except for an excusable and not unnatural helplessness at the crisis of the
# Generated Excerpt:
#  elopement , and the gentleman the young ladies were arrived . sir john and mrs
#
# step 26800 loss 1.8309394121170044
#      Real Excerpt:
#  my character . " " nor do i think it a part of marianne '
# Generated Excerpt:
#  s peace - - but i shall not be able to give . " "
#
# step 27000 loss 1.8376986980438232
#      Real Excerpt:
#  his mother must provide for him sometime or other ; but poor edward is so
# Generated Excerpt:
#  well . i am sure jane saw , and so happy ! i am sure
#
# step 27200 loss 1.887587070465088
#      Real Excerpt:
#  easier to him , as he declared a much greater willingness to make mean concessions
# Generated Excerpt:
#  by seeking its walls , and a happier conclusion , must be an unpleasant thing
#
# step 27400 loss 1.736519694328308
#      Real Excerpt:
#  herself could be , and unconsciously closed his book . he was directly invited to
# Generated Excerpt:
#  give up and part with the next morning ' s ; and he was still
#
# step 27600 loss 1.8888132572174072
#      Real Excerpt:
#  in as he came off ; poor lucy in such a condition , he says
# Generated Excerpt:
#  he is what he has , and i can make off . " " he
#
# step 27800 loss 1.7603778839111328
#      Real Excerpt:
#  . a hundred a year would make them all perfectly comfortable . " his wife
# Generated Excerpt:
#  hesitated a little , however , in such a mode of the world , as
#
# step 28000 loss 1.6420029401779175
#      Real Excerpt:
#  head , by turns . “ well , well , and so mr . bingley
# Generated Excerpt:
#  ’ s , i am convinced that he was a very agreeable man person who
#
# step 28200 loss 1.8087005615234375
#      Real Excerpt:
#  come to us again . ” “ there is some sense in what he says
# Generated Excerpt:
#  about the matter with them , and he is such a good one as to
#
# step 28400 loss 1.6361031532287598
#      Real Excerpt:
#  a countenance , such manners , and so extremely accomplished for her age ! her
# Generated Excerpt:
#  manners were all a smart , and her mother was not striking . her manners
#
# step 28600 loss 1.7744988203048706
#      Real Excerpt:
#  little at netherfield , it would be better for the neighbourhood that he should give
# Generated Excerpt:
#  it with it - - but it would be impossible for her to be to
#
# step 28800 loss 1.78059983253479
#      Real Excerpt:
#  , she knew it was a circumstance which must prejudice her against him . “
# Generated Excerpt:
#  he must be paid it , ” she continued , “ he does not recollect
#
# step 29000 loss 1.5712348222732544
#      Real Excerpt:
#  gutenberg ” is a registered trademark . it may only be used on or associated
# Generated Excerpt:
#  in any way with an associated with the production will be staying at http :
#
# step 29200 loss 1.5772058963775635
#      Real Excerpt:
#  trademark . project gutenberg is a registered trademark , and may not be used if
# Generated Excerpt:
#  you charge for an ebook , you may obtain permission to protect the project gutenberg
#
# step 29400 loss 1.6697686910629272
#      Real Excerpt:
#  the gate in conversation with the ladies ; and sir william , to elizabeth ’
# Generated Excerpt:
#  s deference expects . these were the principal spokesman , the principal object . he
#
# step 29600 loss 1.6167670488357544
#      Real Excerpt:
#  myself without receiving an answer . could there be finer symptoms ? is not general
# Generated Excerpt:
#  incivility the very essence of love ? ” “ that is a wish of love
#
# step 29800 loss 1.5842329263687134
#      Real Excerpt:
#  mean understanding , little information , and uncertain temper . when she was discontented ,
# Generated Excerpt:
#  the subject was no real imprudence that it had been for ever in her power
#
# step 30000 loss 1.5774376392364502
#      Real Excerpt:
#  ? ” “ perfectly so , i thank you . ” she found that she
# Generated Excerpt:
#  was a very short one , and turning away some surprise at home . “
#
# step 30200 loss 1.454624891281128
#      Real Excerpt:
#  in the course of the morning . i will only add , god bless you
# Generated Excerpt:
#  . “ my dear lizzy , ” said she , “ i never saw you
#
# step 30400 loss 1.600050926208496
#      Real Excerpt:
#  she says lizzy had better have taken mr . collins ; but i do not
# Generated Excerpt:
#  know what to think of him , and i am sure i would not have
#
# step 30600 loss 1.527318000793457
#      Real Excerpt:
#  not much signify what one wears this summer , after the - - - -
# Generated Excerpt:
#  - shire have mr . wickham more than once , in a very promising whisper
#
# step 30800 loss 1.519556999206543
#      Real Excerpt:
#  . i hoped to find you reasonable ; but depend upon it i will carry
# Generated Excerpt:
#  my point . i shall not expect it . ” “ i am sorry to
#
# step 31000 loss 1.4637539386749268
#      Real Excerpt:
#  print editions means that no one owns a united states copyright in these works ,
# Generated Excerpt:
#  may could go on no longer be subject to project gutenberg ™ electronic works in
#
# step 31200 loss 1.5635645389556885
#      Real Excerpt:
#  marianne might lose much , he could gain very little by the enforcement of the
# Generated Excerpt:
#  real truth . " " it cannot be but , " said elinor , "
#
# step 31400 loss 1.4242852926254272
#      Real Excerpt:
#  ? he declares he won ' t . don ' t you , mr .
# Generated Excerpt:
#  palmer ? " " i am sure he will be a pretty girl . "
#
# step 31600 loss 1.527264952659607
#      Real Excerpt:
#  . gardiner . elizabeth could not but be pleased , could not but triumph .
# Generated Excerpt:
#  lady catherine seemed of her beauty was a very handsome active magistrate in her expectation
#
# step 31800 loss 1.5476868152618408
#      Real Excerpt:
#  literary archive foundation and how your efforts and donations can help , see sections 3
# Generated Excerpt:
#  and tax tax ( b ) any laws in the case ) what opinions are
#
# step 32000 loss 1.513704538345337
#      Real Excerpt:
#  disgusting rascality . but the hero and the heroine are not tints to be dismissed
# Generated Excerpt:
#  for sir william or lady middleton , and the rest of mr . collins ’
#
# step 32200 loss 1.4878182411193848
#      Real Excerpt:
#  over , they should proceed to longbourn . elizabeth was surprised , however , that
# Generated Excerpt:
#  if its accomplishment is to appertain to the parties in the present of a return
#
# step 32400 loss 1.4634687900543213
#      Real Excerpt:
#  derived from texts not protected by u . s . copyright law ( does not
# Generated Excerpt:
#  contain a it ) : me from a section 1 . f . 3 ,
#
# step 32600 loss 1.460925579071045
#      Real Excerpt:
#  the limited right of replacement or refund set forth in paragraph 1 . f .
# Generated Excerpt:
#  3 , this work is provided to you ‘ as - is ’ , with
#
# step 32800 loss 1.3978766202926636
#      Real Excerpt:
#  impatient to be at home again , and could with difficulty govern her vexation at
# Generated Excerpt:
#  rosings , in a very few steps towards a week , and returned from ,
#
# step 33000 loss 1.3197007179260254
#      Real Excerpt:
#  to have been . he came to tell mr . gardiner that he had found
# Generated Excerpt:
#  out where your father was quite a shocking thing else which marked her sister a
#
# step 33200 loss 1.3168458938598633
#      Real Excerpt:
#  eldest sister , - - “ ah , jane , i take your place now
# Generated Excerpt:
#  , ” she replied ; “ i do not want to be married ? ”
#
# step 33400 loss 1.4897819757461548
#      Real Excerpt:
#  a great coxcomb ! " repeated miss steele , whose ear had caught those words
# Generated Excerpt:
#  offered , a week , before she could go away she could dance with her
#
# step 33600 loss 1.3197271823883057
#      Real Excerpt:
#  my vanity only was elevated by it . careless of her happiness , thinking only
# Generated Excerpt:
#  of its being the introduction , her not to be dancing than that she must
#
# step 33800 loss 1.2546337842941284
#      Real Excerpt:
#  the danger of raising expectations which might only end in disappointment ; for in her
# Generated Excerpt:
#  opinion , she felt all the time must now fall , under such an ecstasy
#
# step 34000 loss 1.3859927654266357
#      Real Excerpt:
#  it would intrude , could not engross her . lydia - - the humiliation ,
# Generated Excerpt:
#  the youngest of the youngest , was the far reasonable information , and the folly
#
# step 34200 loss 1.3204796314239502
#      Real Excerpt:
#  " i do not attempt to deny , " said she , " that i
# Generated Excerpt:
#  have been very much in hertfordshire . " " you are very much mistaken ,
#
# step 34400 loss 1.3408464193344116
#      Real Excerpt:
#  is so natural in lady middleton ; and for my part , i love to
# Generated Excerpt:
#  be happy to have had a gentleman from the young woman of the young man
#
# step 34600 loss 1.3049402236938477
#      Real Excerpt:
#  gayer tone , “ is it in address that he improves ? has he deigned
# Generated Excerpt:
#  to add aught of civility to his widow and ? for i was fortunate as
#
# step 34800 loss 1.262973427772522
#      Real Excerpt:
#  this unfortunate affair will , i fear , prevent my sister ’ s having the
# Generated Excerpt:
#  connection with her , that i should want to say in the character of others
#
# step 35000 loss 1.2261027097702026
#      Real Excerpt:
#  regained her composure , and calmly replied , - - “ why should you be
# Generated Excerpt:
#  surprised , when you cease me to tell you , and very indifferent , if
#
# step 35200 loss 1.178424596786499
#      Real Excerpt:
#  a perfect agreement between them . from that moment she doubted not of their being
# Generated Excerpt:
#  together , after a hearing , which she might be able to notice from the
#
# step 35400 loss 1.2804930210113525
#      Real Excerpt:
#  absence , i may reasonably hope to have all my expectations of pleasure realized .
# Generated Excerpt:
#  " " i think very much more if she would be kind to him as
#
# step 35600 loss 1.3645685911178589
#      Real Excerpt:
#  enough . but it was her business to be satisfied - - and certainly her
# Generated Excerpt:
#  brother for them . but mrs . dashwood had not been aware of the others
#
# step 35800 loss 1.2389111518859863
#      Real Excerpt:
#  piece ! " " oh that they would ! " cried marianne , her eyes
# Generated Excerpt:
#  opposed sister with such attention as if she had now been unknown to , "
#
# step 36000 loss 1.2933018207550049
#      Real Excerpt:
#  was stronger alone , and her own good sense so well supported her , that
# Generated Excerpt:
#  the two miss dashwoods might be , and the first during as they chose twice
#
# step 36200 loss 1.1981145143508911
#      Real Excerpt:
#  heart , which had undergone many changes in the course of this extraordinary conversation ,
# Generated Excerpt:
#  were now another . elinor , when this event was delivered to soothe sense of
#
# step 36400 loss 1.25443434715271
#      Real Excerpt:
#  myself a more wretched condition . we must all feel for him ; and the
# Generated Excerpt:
#  consciousness of it , i know him to be a comfort to him . it
#
# step 36600 loss 1.3471853733062744
#      Real Excerpt:
#  her cousin prefaced his speech with a solemn bow , and though she could not
# Generated Excerpt:
#  hear a word , and then said , in reply to marianne there , -
#
# step 36800 loss 1.215114712715149
#      Real Excerpt:
#  and the disturbance of his mind was visible in every feature . he was struggling
# Generated Excerpt:
#  for the appearance of composure , but for such a serious attachment to elinor ,
#
# step 37000 loss 1.23853600025177
#      Real Excerpt:
#  is said to be low ; but we have it on very hard terms ,
# Generated Excerpt:
#  if we had not . i have not been kept beyond her for her imagination
#
# step 37200 loss 1.1057859659194946
#      Real Excerpt:
#  . " " and for your own sake too , or you are carrying your
# Generated Excerpt:
#  desire . " " i am sure , " said she , " that to
#
# step 37400 loss 1.099010944366455
#      Real Excerpt:
#  disk or other medium , a computer virus , or computer codes that damage or
# Generated Excerpt:
#  cannot be read by the place . 1 . f . 2 . limited warranty
#
# step 37600 loss 1.1842260360717773
#      Real Excerpt:
#  same explanation . " was there no one else in the carriage ? " "
# Generated Excerpt:
#  " no . i have certainly it to be good . " " " and
#
# step 37800 loss 1.083135724067688
#      Real Excerpt:
#  were made by the latter . it had not been very great ; he had
# Generated Excerpt:
#  been so anxious for some days , and in the same situation . from all
#
# step 38000 loss 1.1072983741760254
#      Real Excerpt:
#  was to all her vanity and pride . she fell into violent hysterics immediately ,
# Generated Excerpt:
#  with such screams as reached the door of being not to be immediately , the
#
# step 38200 loss 1.0598026514053345
#      Real Excerpt:
#  ” “ may i ask to what these questions tend ? ” “ merely to
# Generated Excerpt:
#  expose a sigh . she . she . she required most kind , because she
#
# step 38400 loss 1.0845222473144531
#      Real Excerpt:
#  away . but before she had been three minutes in her own room , her
# Generated Excerpt:
#  absence told her in silence . they were , in silence , and in silence
#
# step 38600 loss 1.1440235376358032
#      Real Excerpt:
#  he might reasonably hope to live many years , and by living economically , lay
# Generated Excerpt:
#  and a great deal , and very genteel , when edward ' s having much
#
# step 38800 loss 1.0415986776351929
#      Real Excerpt:
#  which spoke no indifference to the plan , immediately gave a grateful but absolute denial
# Generated Excerpt:
#  , she could take the loss of many a probable motive during your ceremony .
#
# step 39000 loss 1.0740785598754883
#      Real Excerpt:
#  elinor felt all the reasonableness of the idea , and it gave fresh misery to
# Generated Excerpt:
#  her happiness ; and after talking the carriage drove off , she observed , -
#
# step 39200 loss 1.0452690124511719
#      Real Excerpt:
#  you , sir john , when you spoke to me about it before , that
# Generated Excerpt:
#  he might not have been so very angry . but i have no reason with
#
# step 39400 loss 1.0748182535171509
#      Real Excerpt:
#  , if i distress you ; leave me , hate me , forget me !
# Generated Excerpt:
#  how and were you , as it over as fast as i might be .
#
# step 39600 loss 0.9578658938407898
#      Real Excerpt:
#  it . " " that is a material consideration undoubtedly . a valuable legacy indeed
# Generated Excerpt:
#  ! very happy , very happy . a man of such a thing , very
#
# step 39800 loss 0.9821456670761108
#      Real Excerpt:
#  it is quite a pity he should be so grave and so dull . mamma
# Generated Excerpt:
#  , pray do not go . ” “ i am afraid of they insist upon
#
# step 40000 loss 1.0171219110488892
#      Real Excerpt:
#  it all out of her , my dear . she will tell you any thing
# Generated Excerpt:
#  if you please on it . i have nothing either of the very young people
#
# step 40200 loss 1.0392849445343018
#      Real Excerpt:
#  with all the forbearance of civility ; and at the request of the gentlemen remained
# Generated Excerpt:
#  no other misfortune . it was no longer before her ; that she saw every
#
# step 40400 loss 1.060207724571228
#      Real Excerpt:
#  sir john or lady middleton ' s head ; and therefore very little leisure was
# Generated Excerpt:
#  given by him . and as i suppose it must be , i can only
#
# step 40600 loss 1.0987515449523926
#      Real Excerpt:
#  couched ? it must have been only to one end . my business was to
# Generated Excerpt:
#  see them in all i am glad of them . " " i am afraid
#
# step 40800 loss 0.994556188583374
#      Real Excerpt:
#  . org this web site includes information about project gutenberg - tm , including how
# Generated Excerpt:
#  to make donations to the project gutenberg literary archive foundation , how to help produce
#
# step 41000 loss 1.0005346536636353
#      Real Excerpt:
#  , madam , speak lower . what advantage can it be to you to offend
# Generated Excerpt:
#  mr . willoughby ? contrive it cannot depend on her . this is whether she
#
# step 41200 loss 1.0842894315719604
#      Real Excerpt:
#  in short , that means might have been found . but now it is all
# Generated Excerpt:
#  too late . ” “ i do not believe anything ! and how pleased i
#
# step 41400 loss 0.975712776184082
#      Real Excerpt:
#  more eligible visitors . the idea soon reached to conviction , as she observed his
# Generated Excerpt:
#  grievances for bringing the last look , and now returned to the business . "
#
# step 41600 loss 1.0498329401016235
#      Real Excerpt:
#  , and she finished the letter ; “ and , my dear aunt , if
# Generated Excerpt:
#  you do not like to go with me , for it pleased our welfare and
#
# step 41800 loss 0.9230592250823975
#      Real Excerpt:
#  . my sisters may write to me . they will have nothing else to do
# Generated Excerpt:
#  . ” “ i am very sensible of your own , madam , ” said
#
# step 42000 loss 0.9835035800933838
#      Real Excerpt:
#  another day i will do the same ; i will sit in my library ,
# Generated Excerpt:
#  and well agreed unhappy . " " perhaps , " said marianne , " that
#
# step 42200 loss 0.9431025981903076
#      Real Excerpt:
#  bennet made no answer . “ do not you want to know who has taken
# Generated Excerpt:
#  , but not doors equally to condescend to his hearty condescension , or why is
#
# step 42400 loss 0.95052570104599
#      Real Excerpt:
#  yes , almost every day . ” “ his manners are very different from his
# Generated Excerpt:
#  general abuse for friends . ” “ and i am not at all able to
#
# step 42600 loss 0.8974831700325012
#      Real Excerpt:
#  of mind as she was now in , elinor had no difficulty in obtaining from
# Generated Excerpt:
#  her mother the rest of her present humanity , when her present relief to which
#
# step 42800 loss 0.8612585067749023
#      Real Excerpt:
#  of his errand , this was his voluntary communication - - " i suppose you
# Generated Excerpt:
#  have heard , " said she , " how did such an account of removal
#
# step 43000 loss 1.0134602785110474
#      Real Excerpt:
#  with others . his doing so drew her notice . it was at sir william
# Generated Excerpt:
#  lucas ’ s , and he had been numerous , the conquest of his own
#
# step 43200 loss 0.8962813019752502
#      Real Excerpt:
#  , if you will favour me with your company . ” “ go , my
# Generated Excerpt:
#  dear , ” cried her mother , “ for his wife , and we have
#
# step 43400 loss 0.8463728427886963
#      Real Excerpt:
#  bewitched by any woman as he was by her . he really believed that ,
# Generated Excerpt:
#  though he had not an excellent and solemn , and how soon he would have
#
# step 43600 loss 0.8979585766792297
#      Real Excerpt:
#  certain that the air of london would agree with lady lucas . ” he paused
# Generated Excerpt:
#  in hopes of an hour ’ s sees such terms as he had hoped that
#
# step 43800 loss 0.9719759225845337
#      Real Excerpt:
#  and a slight intermission of screams in the young lady on hearing it , gave
# Generated Excerpt:
#  them pleasure . they were all in a violent wished for a moment or other
#
# step 44000 loss 0.9370025992393494
#      Real Excerpt:
#  and in a determined silence when obliged to endure it . her heart was hardened
# Generated Excerpt:
#  against the expectation of mrs . jennings ' s disposition , which , in her
#
# step 44200 loss 0.8517658114433289
#      Real Excerpt:
#  - of what are you thinking ? are the shades of pemberley to be thus
# Generated Excerpt:
#  polluted ? ” “ you can now have no regard to be now , ”
#
# step 44400 loss 0.956034779548645
#      Real Excerpt:
#  of his general behaviour was sharpened into particular resentment by his having slighted one of
# Generated Excerpt:
#  her daughters . elizabeth found her sister very well , and was forced to be
#
# step 44600 loss 0.9079512357711792
#      Real Excerpt:
#  think . the clouds seem parting too , the sun will be out in a
# Generated Excerpt:
#  new - - she will be able to hear . " here mrs . jennings
#
# step 44800 loss 0.9446592926979065
#      Real Excerpt:
#  of sense and sensibility is connected one of those minor problems which delight the cummin
# Generated Excerpt:
#  - splitters of criticism . in the cecilia of madame d ' arblay - -
#
# step 45000 loss 0.8660488128662109
#      Real Excerpt:
#  , as to a real , strong attachment . pray , how violent was mr
# Generated Excerpt:
#  . darcy ’ s love at once more than on dinner , could be of
#
# step 45200 loss 0.8871312737464905
#      Real Excerpt:
#  stated on such authority , elinor could not withhold her credit ; nor was she
# Generated Excerpt:
#  ever felt for a moment for marianne , which she felt very soon discovered to
#
# step 45400 loss 0.8781036138534546
#      Real Excerpt:
#  would be surprised to hear how often i watched you , how often i was
# Generated Excerpt:
#  forced says my middleton had been in every respect for me to introduce you at
#
# step 45600 loss 0.8438546657562256
#      Real Excerpt:
#  . wickham is by no means a respectable young man . i am afraid he
# Generated Excerpt:
#  has often missed his air . he has done for wickham ’ s behaviour to
#
# step 45800 loss 0.860908567905426
#      Real Excerpt:
#  very large one , i know ; and when i come to see you ,
# Generated Excerpt:
#  i hope you will have it in despair it . " " indeed , "
#
# step 46000 loss 0.8152371048927307
#      Real Excerpt:
#  to remove to cleveland about the end of march , for the easter holidays ;
# Generated Excerpt:
#  and mrs . jennings , in her absence of all people , who had been
#
# step 46200 loss 0.8624252676963806
#      Real Excerpt:
# ...
#
# step 85600 loss 0.49701350927352905
#      Real Excerpt:
#  mr . collins , was a most humiliating picture ! and to the pang of
# Generated Excerpt:
#  a friend disgracing herself , and , that though , in a short time ,
#
# step 85800 loss 0.5093557834625244
#      Real Excerpt:
#  the nature of my feelings for him she means ( most kindly ! ) to
# Generated Excerpt:
#  put me on my guard . can there be any other opinion on the subject
#
# step 86000 loss 0.5619553923606873
#      Real Excerpt:
#  less gay or less happy in the smiles of your sister ? no , he
# Generated Excerpt:
#  is grave and does not know the whole to be wished . ” “ not
#
# step 86200 loss 0.503721296787262
#      Real Excerpt:
#  thither ; and her curiosity to know what he had to tell her was heightened
# Generated Excerpt:
#  by the same kind of wives , she felt it ready to accept it scarcely
#
# step 86400 loss 0.5243232846260071
#      Real Excerpt:
#  moment , and then replied , - - “ the engagement between them is of
# Generated Excerpt:
#  time , and there is also and what has passed . my poor mother is
#
# step 86600 loss 0.5060133337974548
#      Real Excerpt:
#  from lady catherine . she had been graciously pleased to approve of both the discourses
# Generated Excerpt:
#  which he had already had the honour of preaching before her . she had also
#
# step 86800 loss 0.484731525182724
#      Real Excerpt:
#  , believed enough to make her former assurance of her sister ’ s ruin still
# Generated Excerpt:
#  more certain ; and even jane , who believed still less of it , became
#
# step 87000 loss 0.5162152051925659
#      Real Excerpt:
#  however this remonstrance might have staggered or delayed his determination , i do not suppose
# Generated Excerpt:
#  that it was not in town , for she was probably heartily meant no better
#
# step 87200 loss 0.541079044342041
#      Real Excerpt:
#  much less notable sketch in drab of another . only genius could have made charlotte
# Generated Excerpt:
#  what she is , that the other ill - judged a young and attentive smile
#
# step 87400 loss 0.4693416357040405
#      Real Excerpt:
#  it is close to the church , and only a quarter of a mile from
# Generated Excerpt:
#  the turnpike - road , so ' tis never dull , for if you only
#
# step 87600 loss 0.44787928462028503
#      Real Excerpt:
#  engaged much of mrs . dashwood ' s attention ; for she was , at
# Generated Excerpt:
#  liberty to wait for the chief of nothing to be waiting for . they met
#
# step 87800 loss 0.5133152604103088
#      Real Excerpt:
#  said elinor , with a smile , " from what i have witnessed this morning
# Generated Excerpt:
#  . i should never deserve she could recollect you . " elinor , and bid
#
# step 88000 loss 0.5077511072158813
#      Real Excerpt:
#  medium with your written explanation . the person or entity that provided you with the
# Generated Excerpt:
#  defective work may elect to provide a replacement copy in lieu of a refund .
#
# step 88200 loss 0.4948497414588928
#      Real Excerpt:
#  any respect less happy at longstaple than he used to be . i do not
# Generated Excerpt:
#  mean to say that i am particularly observant or quick - sighted in general ,
#
# step 88400 loss 0.47767674922943115
#      Real Excerpt:
#  or he would never have called on us in this familiar way . ” but
# Generated Excerpt:
#  when elizabeth told of it , she found that he had been allowed him before
#
# step 88600 loss 0.4913620352745056
#      Real Excerpt:
#  by representing the inconveniences which that indulgent mother must draw on herself , if (
# Generated Excerpt:
#  had been public in life more than the case ) than in whatever manner he
#
# step 88800 loss 0.508801281452179
#      Real Excerpt:
#  you . we know how little there is to tempt anyone to our humble abode
# Generated Excerpt:
#  . our plain manner of living , our small rooms , and our small little
#
# step 89000 loss 0.4917799234390259
#      Real Excerpt:
#  long expected ball at netherfield , which was fixed for the following tuesday . the
# Generated Excerpt:
#  next morning after their arrival of the company by her reaching elizabeth with a sensible
#
# step 89200 loss 0.5094835162162781
#      Real Excerpt:
#  the sweetest temper i ever met with . i often tell my other girls they
# Generated Excerpt:
#  are rich in . i believe , though the world harm to be together ;
#
# step 89400 loss 0.5043504238128662
#      Real Excerpt:
#  , ” said darcy . “ of a fine , stout , healthy love it
# Generated Excerpt:
#  may . i ask . he has a living of poetry in the - -
#
# step 89600 loss 0.49760621786117554
#      Real Excerpt:
#  my curricle ? " " yes , yes , mr . impudence , i know
# Generated Excerpt:
#  that i had not forgot , and i had not seen enough to tell you
#
# step 89800 loss 0.5412923693656921
#      Real Excerpt:
#  , and i am sure has been faithfully kept so by me to this hour
# Generated Excerpt:
#  . not a soul of all my family , i lucas ; for the means
#
# step 90000 loss 0.49732568860054016
#      Real Excerpt:
#  , and really believed to be her feelings , in the expectation of his arrival
# Generated Excerpt:
#  , and was still very unexpected near her countenance . mrs . gardiner did say
#
# step 90200 loss 0.5136773586273193
#      Real Excerpt:
#  replacement or refund set forth in paragraph 1 . f . 3 , this work
# Generated Excerpt:
#  is provided to you ‘ as - is ’ , with no other warranties of
#
# step 90400 loss 0.4938572645187378
#      Real Excerpt:
#  constant , which ever we are to call it , has subsisted through all the
# Generated Excerpt:
#  time to use of it . well , he is , cannot know few women
#
# step 90600 loss 0.5218043923377991
#      Real Excerpt:
#  on the very day of her arrival at pemberley - - for she had reached
# Generated Excerpt:
#  it only to another woman to introduce lady catherine . “ i am always left
#
# step 90800 loss 0.5093971490859985
#      Real Excerpt:
#  the command of countenance with which charlotte talked of the healthfulness of the exercise ,
# Generated Excerpt:
#  and owned she encouraged it as much as possible . here , leading the way
#
# step 91000 loss 0.48914748430252075
#      Real Excerpt:
#  do with his own time has no conscience in his intrusion on that of others
# Generated Excerpt:
#  . the emotion which being acted made very naturally at least quite granted ! and
#
# step 91200 loss 0.5212195515632629
#      Real Excerpt:
#  to be sure , the good lady who showed us the house did give him
# Generated Excerpt:
#  her there for a few days . it was the last hour , that elinor
#
# step 91400 loss 0.4958632290363312
#      Real Excerpt:
#  me a vast deal of money . " " more than you think it really
# Generated Excerpt:
#  should be in the same way . " " you have heard so , sir
#
# step 91600 loss 0.5328312516212463
#      Real Excerpt:
#  only genius knows . the one was humanity , and the other was art .
# Generated Excerpt:
#  her countenance was not more quiet , because it were notice of the event ,
#
# step 91800 loss 0.5196773409843445
#      Real Excerpt:
#  arrived in due time at the place of destination , and as soon as the
# Generated Excerpt:
#  string of carriages ’ names to possession , and altogether in hearing this , one
#
# step 92000 loss 0.48801934719085693
#      Real Excerpt:
#  that such an effusion was heard only by herself , soon went away . but
# Generated Excerpt:
#  this was astonishing in she could not answer , and her mind was entirely !
#
# step 92200 loss 0.4321780204772949
#      Real Excerpt:
#  agreeable to lady middleton . with her children they were in continual raptures , extolling
# Generated Excerpt:
#  their beauty , courting their notice , and humouring their whims ; and such of
#
# step 92400 loss 0.4998677670955658
#      Real Excerpt:
#  it was , it required but a slight effort of fancy to connect his emotion
# Generated Excerpt:
#  with the clever bennet . bingley expressed to give him with the idea of her
#
# step 92600 loss 0.501631498336792
#      Real Excerpt:
#  " said charlotte , " when he is in parliament ! - - won '
# Generated Excerpt:
#  t it ? how i don ' t speak to you nieces at the expense
#
# step 92800 loss 0.5116780996322632
#      Real Excerpt:
#  any other colour , if he had not happened to say so . my cousins
# Generated Excerpt:
#  , i am quite delighted with him , for he never in the death of
#
# step 93000 loss 0.48621073365211487
#      Real Excerpt:
#  sixteen . perhaps she is full young to be much in company . but really
# Generated Excerpt:
#  , i am afraid , i am afraid it is not to think we must
#
# step 93200 loss 0.46907514333724976
#      Real Excerpt:
#  of me than you did ? " - - said he , letting it fall
# Generated Excerpt:
#  , " and walked about the window , i had no meeting with me ,
#
# step 93400 loss 0.4621659219264984
#      Real Excerpt:
#  anxious solicitude on marianne ' s feeling , in her head and throat , the
# Generated Excerpt:
#  carriage might be of the most unfortunate truth . the evening was the last time
#
# step 93600 loss 0.5120238065719604
#      Real Excerpt:
#  declare for pride and prejudice unhesitatingly . it seems to me the most perfect ,
# Generated Excerpt:
#  the most eminently obsoletenesses that true smartness may undoubtedly are not secure , and in
#
# step 93800 loss 0.49265429377555847
#      Real Excerpt:
#  ! " " disappointment ? " " yes , for i am unable to keep
# Generated Excerpt:
#  my engagement with you . mrs . smith has this morning exercised the privilege of
#
# step 94000 loss 0.508476972579956
#      Real Excerpt:
#  had been insolent and unjust ; with a heart hardened against their merits , and
# Generated Excerpt:
#  led off here from their brother ’ s frailty would be so much more than
#
# step 94200 loss 0.5430830121040344
#      Real Excerpt:
#  " said he . " to me it is faultless . nay , more ,
# Generated Excerpt:
#  i wish to be kind or prettier than yourself . i am afraid of her
#
# step 94400 loss 0.5222388505935669
#      Real Excerpt:
#  replied elizabeth , “ where nothing is in question but the desire of being well
# Generated Excerpt:
#  - behaved , it is faultless , and nothing had been connected by herself -
#
# step 94600 loss 0.5110254287719727
#      Real Excerpt:
#  brandon , and even the boisterous mirth of sir john and his mother - in
# Generated Excerpt:
#  - law was interesting . lady middleton seemed to be only the time , who
#
# step 94800 loss 0.5407821536064148
#      Real Excerpt:
#  , and we must expect him to keep or quit it on the same principle
# Generated Excerpt:
#  . ” “ lizzy , or whom i question but i am bought , ”
#
# step 95000 loss 0.47814568877220154
#      Real Excerpt:
#  was to be tempted to eat by every delicacy in the house , and to
# Generated Excerpt:
#  the day , she languid pain very much conversation with her the church . ”
#
# step 95200 loss 0.5410559177398682
#      Real Excerpt:
#  ( by - the - bye , mrs . forster and me are such friends
# Generated Excerpt:
#  as had then been through the regiment , i should have said so much reason
#
# step 95400 loss 0.4448131024837494
#      Real Excerpt:
#  determine the status of compliance for any particular state visit www . gutenberg . org
# Generated Excerpt:
#  / donate . while we cannot and do not solicit contributions from states where we
#
# step 95600 loss 0.4735259711742401
#      Real Excerpt:
#  arts did he use to separate them ? ” “ he did not talk to
# Generated Excerpt:
#  many connected upon his daughters . ” “ and do you think it incredible to
#
# step 95800 loss 0.4959788918495178
#      Real Excerpt:
#  am not her particular friend . i have just as much right to be asked
# Generated Excerpt:
#  as one of derbyshire in the world , and i could have been always used
#
# step 96000 loss 0.45641759037971497
#      Real Excerpt:
#  almost every day . she not unfrequently stopped at the parsonage , and had a
# Generated Excerpt:
#  few minutes ’ conversation with charlotte , but was scarcely ever prevailed on to get
#
# step 96200 loss 0.48729339241981506
#      Real Excerpt:
#  spoke at all ; but when the servants were withdrawn , he thought it time
# Generated Excerpt:
#  to call for having prevailed on to accept him ; but now he never did
#
# step 96400 loss 0.5237794518470764
#      Real Excerpt:
#  my acquaintance , were i distractedly in love with him , i cannot say that
# Generated Excerpt:
#  i regret my comparative insignificance . importance may sometimes be purchased too dearly . kitty
#
# step 96600 loss 0.49079862236976624
#      Real Excerpt:
#  quartered in meryton . the time fixed for the beginning of their northern tour was
# Generated Excerpt:
#  now fast approaching ; and a lover , which naturally fixed the reception of his
#
# step 96800 loss 0.4872713088989258
#      Real Excerpt:
#  the furniture was all sent around by water . it chiefly consisted of household linen
# Generated Excerpt:
#  , than before the difference between them , the same , the same , the
#
# step 97000 loss 0.4944154918193817
#      Real Excerpt:
#  her spirits unnecessary ; nothing , therefore , could be fairly conjectured from that ,
# Generated Excerpt:
#  - - though elizabeth , who was by he could not himself , could not
#
# step 97200 loss 0.43875735998153687
#      Real Excerpt:
#  said lydia , as they sat down to table . “ what do you think
# Generated Excerpt:
#  of very hard ; but if you promise me , to be a charming woman
#
# step 97400 loss 0.520079493522644
#      Real Excerpt:
#  “ this is wholly unexpected ; i had not an idea of it . ”
# Generated Excerpt:
#  “ i should never have been really in town ; and i assure you i
#
# step 97600 loss 0.4802604019641876
#      Real Excerpt:
#  how you could think of such a thing ? i write to the doctor ,
# Generated Excerpt:
#  but i am not so agreeable for it . " elinor then heard , and
#
# step 97800 loss 0.46611693501472473
#      Real Excerpt:
#  comfortable to her . he seemed really anxious to accommodate them and the whole of
# Generated Excerpt:
#  his letter was written to the place , from his letter was written to the
#
# step 98000 loss 0.478277325630188
#      Real Excerpt:
#  , recollecting that fanny was yet uninformed of her sister ' s being there ,
# Generated Excerpt:
#  whom she wished ) of her colour ! what she had used to say to
#
# step 98200 loss 0.4674263298511505
#      Real Excerpt:
#  and instantly followed by willoughby himself , rushing eagerly into the room to enforce ,
# Generated Excerpt:
#  till one thoughts . the whole of his eyes were fixed on him . the
#
# step 98400 loss 0.5022020936012268
#      Real Excerpt:
#  the house was small and indifferent ; an evil which elinor , as mrs .
# Generated Excerpt:
#  jennings had supposed her to do , made very light of , at least as
#
# step 98600 loss 0.5087929964065552
#      Real Excerpt:
#  rattle of the chaise . elizabeth loved absurdities , but she had known sir william
# Generated Excerpt:
#  ’ s disposition , and rode the square . they had they now found at
#
# step 98800 loss 0.5512893199920654
#      Real Excerpt:
#  manner so little agreeable to her . “ are you not diverted ? ” “
# Generated Excerpt:
#  that is to say very cautious , ” said she to fanny does not -
#
# step 99000 loss 0.515167772769928
#      Real Excerpt:
#  , he had spoken to her but little , but every five minutes seemed to
# Generated Excerpt:
#  make it to him only to him many weeks . " " perhaps it would
#
# step 99200 loss 0.4442138373851776
#      Real Excerpt:
#  opportunity of paying the parting civilities which he deemed indispensably necessary . “ i know
# Generated Excerpt:
#  not , ” said she , “ if it would be a ball was quite
#
# step 99400 loss 0.44357919692993164
#      Real Excerpt:
#  trade , and within view of his own warehouses , could have been so well
# Generated Excerpt:
#  - bred and agreeable . mrs . gardiner , who was several years younger than
#
# step 99600 loss 0.4709015190601349
#      Real Excerpt:
#  together because their passions were stronger than their virtue , she could easily conjecture .
# Generated Excerpt:
#  but upon yourself , i seemed to do . i will try you next to
#
# step 99800 loss 0.4838449954986572
#      Real Excerpt:
#  not in themselves illaudable , appeared to her not merely an unnecessary effort , but
# Generated Excerpt:
#  a disgraceful subjection of reason to common - place and mistaken notions . willoughby thought
#
# step 100000 loss 0.42716625332832336
#      Real Excerpt:
#  was now in an irritation as violent from delight as she had ever been fidgety
# Generated Excerpt:
#  from alarm and vexation . to know that her daughter would be married was first

# %%
plt.plot(losses)

# %%
print(d_model, block_size, n_blocks, n_heads, len(vocab), step)
# Out:
# 64 128 4 4 9378 100000

# %%
## Save model to reload later
model_2Mparams = {
    "model_state": model.state_dict(),
    "opt_state": opt.state_dict(),
    "step": step,
    "config": dict(
        vocab_size=len(vocab),
        block_size=block_size,
        d_model=128,
        n_blocks=n_blocks,
        n_heads=n_heads,
        d_ff=512,
    ),
}
torch.save(model_2Mparams, "miniGPT_2Mparams.pt")

# %% [markdown]
# # Attention Heatmap

# %%
# # Take one excerpt, idx 
# model.eval()
# idx, _ = get_batch(ids, batch_size=1, block_size=64) 
# with torch.no_grad():
#     _, attn_maps = model(idx, return_attn=True)

# # Define #batches (1), token length (T), #blocks, and #heads 
# B, T = idx.shape
# n_blocks = len(attn_maps)
# n_heads =  attn_maps[0].shape[1]
# print("TEXT:\n", " ".join(itos[i] for i in idx[0].tolist()))
# print(n_blocks, n_heads, np.shape(attn_maps))

# %%
# Try to make a repeated random sequence ... 
L = 16
base, _ = get_batch(ids, batch_size=1000, block_size=L)
idx = torch.cat([base, base, base, base], dim=1)
with torch.no_grad():
    _, attn_maps = model(idx, return_attn=True)

# Define #batches (1), token length (T), #blocks, and #heads 
B, T = idx.shape
n_blocks = len(attn_maps)
n_heads =  attn_maps[0].shape[1]
print("TEXT:\n", " ".join(itos[i] for i in idx[0].tolist()))
# Out:
# TEXT:
#  with excellent abilities and an excellent disposition , was neither reasonable nor candid . she expected with excellent abilities and an excellent disposition , was neither reasonable nor candid . she expected with excellent abilities and an excellent disposition , was neither reasonable nor candid . she expected with excellent abilities and an excellent disposition , was neither reasonable nor candid . she expected

# %%
# Repeat vs control, then you'll plot Δ = (repeat - control) later
L = 16
base, _ = get_batch(ids, batch_size=1500, block_size=L)

idx_rep = torch.cat([base, base, base, base], dim=1)
rand2, _ = get_batch(ids, batch_size=1500, block_size=L)
rand3, _ = get_batch(ids, batch_size=1500, block_size=L)
rand4, _ = get_batch(ids, batch_size=1500, block_size=L)
idx_ctl = torch.cat([base, rand2, rand3, rand4], dim=1)

with torch.no_grad():
    _, attn_rep = model(idx_rep, return_attn=True)
    _, attn_ctl = model(idx_ctl, return_attn=True)

B, T = idx_rep.shape
n_blocks = len(attn_rep)
n_heads  = attn_rep[0].shape[1]
print("TEXT (repeat):\n", " ".join(itos[i] for i in idx_rep[0].tolist()))
# Out:
# TEXT (repeat):
#  so , they could not succeed . by supposing such an affection , you make everybody so , they could not succeed . by supposing such an affection , you make everybody so , they could not succeed . by supposing such an affection , you make everybody so , they could not succeed . by supposing such an affection , you make everybody

# %%
## Plot Heatmap
from matplotlib.colors import LogNorm
fig, axes = plt.subplots(n_blocks, n_heads, figsize=(2*n_heads, 2*n_blocks))
for b in range(n_blocks): 
    # A = attn_maps[b].mean(dim=0).detach().cpu().numpy() # take the first batch B ( shape = (n,T,T) ) 
    A_rep = attn_rep[b].mean(dim=0).detach().cpu().numpy()   # (H,T,T)
    A_ctl = attn_ctl[b].mean(dim=0).detach().cpu().numpy()
    A = A_rep - A_ctl     
    for h in range(n_heads):
        # M = A[h, 32:64, :32]
        L = 16; k = 1;
        M = A[h, k*L:(k+1)*L, (k-1)*L:k*L]
        ax = axes[b, h] 
        # M = M / (M.sum(axis=1, keepdims=True) + 1e-9)
        # M = M - M.mean(axis=1, keepdims=True)
        # ax.imshow(M, aspect="auto", origin="upper")
        ax.imshow(A[h][L:4*L, L:4*L], aspect="auto", origin="upper")
        ax.set_title(f"Block {b}, Head {h}")
        ax.set_xticks([]); ax.set_yticks([])
        d0  = np.diagonal(M,  0).mean()   # copy
        dm1 = np.diagonal(M, -1).mean()   # induction (t -> t-1)
        dp1 = np.diagonal(M, +1).mean()   # anti-induction (t -> t+1) 
        print("copy", d0, "ind(-1)", dm1, "ind(+1)", dp1, "best", max(dm1,dp1)-d0)

        # Mt = M.T
        # d0  = np.diagonal(Mt, 0).mean()
        # dm1 = np.diagonal(Mt, -1).mean()
        # dp1 = np.diagonal(Mt, +1).mean()
        # print("TRANSPOSED:", d0, dm1, dp1)
plt.tight_layout()
plt.show()
# print the actual tokens / text for the prompt you're plotting
print("TEXT:\n", " ".join(itos[i] for i in idx[0].tolist()))
# Out:
# copy -0.0035548627 ind(-1) 0.0021375038 ind(+1) -0.000415591 best 0.0056923665
# copy 0.0490999 ind(-1) -0.0002975674 ind(+1) -0.00036230803 best -0.04939747
# copy -0.007519889 ind(-1) -0.0005035553 ind(+1) 0.00074573286 best 0.008265622
# copy -0.0077603306 ind(-1) -0.0026731521 ind(+1) 0.0029526884 best 0.0107130185
# copy -0.0025835535 ind(-1) -0.0011172419 ind(+1) 0.00037001737 best 0.0029535708
# copy -0.0032006635 ind(-1) -0.0011411628 ind(+1) 0.002430143 best 0.0056308066
# copy -0.0034380143 ind(-1) -0.0017838675 ind(+1) 0.0065628784 best 0.010000893
# copy -0.006541405 ind(-1) -0.0025735637 ind(+1) 0.0029208034 best 0.0094622085
# copy -0.009982455 ind(-1) -0.00060074514 ind(+1) 0.01127223 best 0.021254685
# copy -0.0039409166 ind(-1) -0.00033902904 ind(+1) 0.003752013 best 0.0076929294
# copy -0.0033976582 ind(-1) 0.0018975097 ind(+1) 0.007378894 best 0.010776552
# copy -0.004517191 ind(-1) -0.0024730868 ind(+1) 0.009997603 best 0.014514794
# copy -0.0032907338 ind(-1) -0.002681156 ind(+1) 0.0020152333 best 0.0053059673
# copy -0.0080724675 ind(-1) -0.0052166833 ind(+1) 0.002523233 best 0.010595701
# copy -0.0043038977 ind(-1) -0.0036266919 ind(+1) 0.0010604629 best 0.0053643608
# copy -0.0043340777 ind(-1) -0.0025452028 ind(+1) 0.0030891055 best 0.007423183
# TEXT:
#  with excellent abilities and an excellent disposition , was neither reasonable nor candid . she expected with excellent abilities and an excellent disposition , was neither reasonable nor candid . she expected with excellent abilities and an excellent disposition , was neither reasonable nor candid . she expected with excellent abilities and an excellent disposition , was neither reasonable nor candid . she expected

# %%
b, h = 0, 3
A = attn_maps[b][0, h].detach().cpu()      # (T,T)
col_mass = A.mean(dim=0)                   # (T,) avg attention paid to each key position
j = int(col_mass.argmax())

print("stripe key index:", j)
print("token there:", itos[idx[0, j].item()])
# Out:
# stripe key index: 29
# token there: forwarded

# %%
6*(12*128**2 + 9*128) + (2+9376+128)*128
# Out:
# 2403328
