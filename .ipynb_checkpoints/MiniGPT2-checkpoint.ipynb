# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch import nn
import torch.nn.functional as F
from tqdm import tqdm
import time
import re
from collections import Counter
import math

# from TransformerModel import *

import importlib, TransformerModel
importlib.reload(TransformerModel)
from TransformerModel import TinyGPT

# %% [markdown]
# # Data Collection

# %%
### ~~~~~~~~~~~~~~~~~~~~~ ###
###    token definition   ###
### ~~~~~~~~~~~~~~~~~~~~~ ###
paths = ["data/PrideAndPrejudice.txt", "data/Emma.txt", "data/SenseAndSensibility.txt"]
text = "\n".join(open(p, "r", encoding="utf-8", errors="ignore").read().lower() for p in paths)

# simple tokenizer: words or single punctuation marks
tokens = re.findall(r"[a-z]+|[0-9]+|[^\s\w]", text)
print("num tokens:", len(tokens), "unique:", len(set(tokens)))
# Out:
# num tokens: 314744 unique: 9376

# %%
### ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ###
###    vocab definition, encoding   ###
### ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ###
vocab_size = 10_000
special = ["<pad>", "<unk>"]  # pad will make each token same length, unk is reserved for words not in vocab

counts = Counter(tokens)
most_common = [w for (w, _) in counts.most_common(vocab_size - len(special))]
vocab = special + most_common

# string-to-index,  index-to-string
stoi = {w:i for i,w in enumerate(vocab)}
itos = {i:w for w,i in stoi.items()}

# ids = entire book written in integers
ids = torch.tensor([stoi.get(tok, stoi["<unk>"]) for tok in tokens], dtype=torch.long)
print("ids shape:", ids.shape, "UNK rate:", (ids == stoi["<unk>"]).float().mean().item())
# Out:
# ids shape: torch.Size([314744]) UNK rate: 0.0

# %%
### ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ###
###    Sentence / Phrase Extractor   ###
### ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ###
# batch_size = number of excerpts
# block_size = length of each excerpt
def get_batch(data_ids, batch_size=32, block_size=128, device="cpu"):
    # random starting indices
    ix = torch.randint(0, len(data_ids) - block_size - 1, (batch_size,))
    x = torch.stack([data_ids[i:i+block_size] for i in ix]).to(device)  ## random sentence / phrase
    y = torch.stack([data_ids[i+1:i+block_size+1] for i in ix]).to(device) ## shifted sentence / phrase
    return x, y

# quick sanity check
x, y = get_batch(ids, batch_size=4, block_size=8)
print(x)
print(x[0].tolist())
print(y[0].tolist())
print([itos[i] for i in x[0].tolist()])
print([itos[i] for i in y[0].tolist()])
# Out:
# tensor([[  53,   36, 1131,    5,    4, 2623,    6,  131],
#         [ 544,    6,   38,   25, 2667,    2, 1453,    9],
#         [  15,  107,   32,    9,  278, 1466,  235,   22],
#         [ 867,    2,   86,   11,  716,  153,   45,   84]])
# [53, 36, 1131, 5, 4, 2623, 6, 131]
# [36, 1131, 5, 4, 2623, 6, 131, 954]
# ["'", 's', 'hands', 'to', 'the', 'amount', 'of', 'two']
# ['s', 'hands', 'to', 'the', 'amount', 'of', 'two', 'hundred']

# %% [markdown]
# # Model Definition & Training

# %%
##  See TransformerModel.py for  
##    -- CausalSelfAttention
##    -- Block = LayerNorm + SelfAtt + LayerNorm + MLP 
##    -- TinyGPT

# %%
B, T, d_model, n_heads = 1, 5, 64, 4
x = torch.randn(B, T, d_model)

attn = CausalSelfAttention(d_model=d_model, n_heads=n_heads, block_size=128);
y1 = attn(x)

# %%
### ~~~~~~~~~~~~~~~~~~~~ ###
###    Model Definition  ###
### ~~~~~~~~~~~~~~~~~~~~ ###
device = "cpu"
# hyperparams
block_size = 128  ## excerpt size (few sentences)
batch_size = 32   ## number of excerpts

model = TinyGPT(vocab_size=len(vocab), block_size=block_size, 
                d_model=256, n_blocks=4, n_heads=4, d_ff=1024).to(device)

n_params = sum(p.numel() for p in model.parameters())
n_trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
print("total params:", n_params)
print("trainable params:", n_trainable)

# optimizer
lr = 3e-4
opt = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=0.1)
# Out:
# total params: 5588992
# trainable params: 5588992

# %%
### ~~~~~~~~~~~~~~~ ###
###    Train Model  ###
### ~~~~~~~~~~~~~~~ ###
def decode(token_ids):
    return " ".join(itos[i] for i in token_ids)


steps = 25_000; 
# losses = []; 
for step in range(1, steps+1):
    ## Get a random excerpt (x) and excerpt+1 (y) 
    x, y = get_batch(ids, batch_size=batch_size, block_size=block_size, device=device)  # (B,T)
    logits = model(x)  # (B,T,V)
    loss = F.cross_entropy(logits.view(-1, len(vocab)), y.view(-1))

    opt.zero_grad()
    loss.backward()
    torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
    opt.step()
    if step % 200 == 0:
        losses.append(loss.item())
        print("step", step, "loss", float(loss))
        # quick greedy sample from last position
        ctx, _ = get_batch(ids, batch_size=1, block_size=15, device=device)
        with torch.no_grad():
            out = ctx.clone()
            for _ in range(15):
                logits = model(out[:, -block_size:])
                next_id = logits[:, -1, :].argmax(dim=-1, keepdim=True)  # choose most likely next token
                out = torch.cat([out, next_id], dim=1)
        prompt_ids = out[0, :15].tolist()
        gen_ids    = out[0, 15:30].tolist()
        print("     Real Excerpt:\n", decode(prompt_ids))
        print("Generated Excerpt:\n", decode(gen_ids))
        print()
# Out:
# step 200 loss 0.14243869483470917
#      Real Excerpt:
#  of what passed at pemberley and lambton ! i owe all that i know of
# Generated Excerpt:
#  it to another , not to you . ” elizabeth told her the motives of
#
# step 400 loss 0.14852485060691833
#      Real Excerpt:
#  . to be tied down to the regular payment of such a sum , on
# Generated Excerpt:
#  every rent day , is by no means desirable : it takes away one '
#
# step 600 loss 0.12857912480831146
#      Real Excerpt:
#  from the first to think marianne ' s complaint more serious than elinor , now
# Generated Excerpt:
#  looked very grave on mr . harris ' s report , and confirming charlotte '
#
# step 800 loss 0.13341863453388214
#      Real Excerpt:
#  visitor . mr . darcy called , and was shut up with him several hours
# Generated Excerpt:
#  . it was all over before i arrived ; so my curiosity was not so
#
# step 1000 loss 0.12380757927894592
#      Real Excerpt:
#  surprise of what had happened : it was impossible to think of anything else ;
# Generated Excerpt:
#  and , totally indisposed for employment , she resolved soon after breakfast to indulge herself
#
# step 1200 loss 0.12800195813179016
#      Real Excerpt:
#  all the principal people in the room : he was lively and unreserved , danced
# Generated Excerpt:
#  every dance , was angry that the ball closed so early , and talked of
#
# step 1400 loss 0.1311783641576767
#      Real Excerpt:
#  - i left london this morning at eight o ' clock , and the only
# Generated Excerpt:
#  ten minutes i have spent out of my chaise since that time procured me a
#
# step 1600 loss 0.11631423979997635
#      Real Excerpt:
#  mend pens remarkably well . ” “ thank you - - but i always mend
# Generated Excerpt:
#  my own . ” “ how can you contrive to write so even ? ”
#
# step 1800 loss 0.13877645134925842
#      Real Excerpt:
#  he could form such a design against a young woman of lydia ’ s connections
# Generated Excerpt:
#  , which is not likely , can i suppose her so lost to everything ?
#
# step 2000 loss 0.12695643305778503
#      Real Excerpt:
#  " said miss steele , affectedly simpering , " everybody laughs at me so about
# Generated Excerpt:
#  the doctor , and i cannot think why . my cousins say they are sure
#
# step 2200 loss 0.12858091294765472
#      Real Excerpt:
#  legacy from mrs . jennings , was the easiest means of atoning for his own
# Generated Excerpt:
#  neglect . they were lucky enough to find lady middleton at home , and sir
#
# step 2400 loss 0.13305899500846863
#      Real Excerpt:
#  were then , that every unpleasant circumstance attending it ought to be forgotten . you
# Generated Excerpt:
#  must learn some of my philosophy . think only of the past as its remembrance
#
# step 2600 loss 0.13049951195716858
#      Real Excerpt:
#  advanced years , and on his forlorn condition as an old bachelor . mrs .
# Generated Excerpt:
#  dashwood , who could not think a man five years younger than herself , so
#
# step 2800 loss 0.13325509428977966
#      Real Excerpt:
#  declared his willingness , and elizabeth was applied to for her approbation . “ my
# Generated Excerpt:
#  love , should not you like to see a place of which you have heard
#
# step 3000 loss 0.12352040410041809
#      Real Excerpt:
#  way , which the other as politely and more earnestly negatived , she seated herself
# Generated Excerpt:
#  . mrs . hurst sang with her sister ; and while they were thus employed
#
# step 3200 loss 0.12311717122793198
#      Real Excerpt:
#  two . " " do you know where they came from ? " " they
# Generated Excerpt:
#  come straight from town , as miss lucy - - mrs . ferrars told me
#
# step 3400 loss 0.12319207191467285
#      Real Excerpt:
#  most advantageously to the critical eye ; and the want of it will sometimes mar
# Generated Excerpt:
#  those graces - - appreciably , though not quite consciously - - to eyes by
#
# step 3600 loss 0.13613174855709076
#      Real Excerpt:
#  ” his wife represented to him how absolutely necessary such an attention would be from
# Generated Excerpt:
#  all the neighbouring gentlemen , on his returning to netherfield . “ ’ tis an
#
# step 3800 loss 0.12455695122480392
#      Real Excerpt:
#  been at all surprised by her ladyship ’ s asking us on sunday to drink
# Generated Excerpt:
#  tea and spend the evening at rosings . i rather expected , from my knowledge
#
# step 4000 loss 0.13304072618484497
#      Real Excerpt:
#  pain - - to what degree you only can tell . but whatever may be
# Generated Excerpt:
#  the sentiments which mr . wickham has created , a suspicion of their nature shall
#
# step 4200 loss 0.12566308677196503
#      Real Excerpt:
#  attachment on either side , ” said jane . “ i am sure there is
# Generated Excerpt:
#  not on his . i will answer for it , he never cared three straws
#
# step 4400 loss 0.12485198676586151
#      Real Excerpt:
#  am no longer surprised at your knowing only six accomplished women . i rather wonder
# Generated Excerpt:
#  now at your knowing any . ” “ are you so severe upon your own
#
# step 4600 loss 0.1314084380865097
#      Real Excerpt:
#  be employed , and every thing conducted in the usual style of a complete party
# Generated Excerpt:
#  of pleasure . to some few of the company it appeared rather a bold undertaking
#
# step 4800 loss 0.1263355314731598
#      Real Excerpt:
#  . but let me advise you to think better of it . i know your
# Generated Excerpt:
#  disposition , lizzy . i know that you could be neither happy nor respectable ,
#
# step 5000 loss 0.1290077418088913
#      Real Excerpt:
#  was grateful for bringing her sister away unseen by willoughby since his marriage , and
# Generated Excerpt:
#  she looked forward with hope to what a few months of tranquility at barton might
#
# step 5200 loss 0.12680169939994812
#      Real Excerpt:
#  punctuality , both kitty and lydia looking out of a dining - room upstairs .
# Generated Excerpt:
#  these two girls had been above an hour in the place , happily employed in
#
# step 5400 loss 0.12573082745075226
#      Real Excerpt:
#  amendment , however , she requested to have a note sent to longbourn , desiring
# Generated Excerpt:
#  her mother , to beg that the living in retirement and agreeable . sir john
#
# step 5600 loss 0.12697532773017883
#      Real Excerpt:
#  well disposed on the whole to regard his actions with all the candid allowances and
# Generated Excerpt:
#  generous qualifications , which had been rather more painfully extorted from her , for willoughby
#
# step 5800 loss 0.12902723252773285
#      Real Excerpt:
#  humility . it is often only carelessness of opinion , and sometimes an indirect boast
# Generated Excerpt:
#  . ” “ and which of the two do you call my little recent piece
#
# step 6000 loss 0.12387438118457794
#      Real Excerpt:
#  pleasing would fail her . she retreated from the window , fearful of being seen
# Generated Excerpt:
#  ; and as she walked up and down the room , endeavouring to compose herself
#
# step 6200 loss 0.1141837015748024
#      Real Excerpt:
#  her for the world . in such circumstances , it was better for both that
# Generated Excerpt:
#  they should not be long together ; and the restless state of marianne ' s
#
# step 6400 loss 0.1273483783006668
#      Real Excerpt:
#  learn some from their aunt . at present , indeed , they were well supplied
# Generated Excerpt:
#  both with news and happiness by the recent arrival of a militia regiment in the
#
# step 6600 loss 0.12470533698797226
#      Real Excerpt:
#  engagements , and new schemes , in which she could have no share , without
# Generated Excerpt:
#  shedding many tears . elinor ' s satisfaction , at the moment of removal ,
#
# step 6800 loss 0.12425204366445541
#      Real Excerpt:
#  was not held there in much estimation ; for though the chief of his concerns
# Generated Excerpt:
#  with the son of his patron were imperfectly understood , it was yet a well
#
# step 7000 loss 0.13215097784996033
#      Real Excerpt:
#  long , long ago . he knows of my being in town , i am
# Generated Excerpt:
#  certain , from something she said herself ; and yet it would seem , by
#
# step 7200 loss 0.12059122323989868
#      Real Excerpt:
#  smiling within herself at the mistake , she honoured her sister for that blind partiality
# Generated Excerpt:
#  to edward which produced it . " i hope , marianne , " continued elinor
#
# step 7400 loss 0.11798985302448273
#      Real Excerpt:
#  as to the time of her having left longbourn , and of her stay in
# Generated Excerpt:
#  derbyshire , so often , and in so hurried a way , as plainly spoke
#
# step 7600 loss 0.13464389741420746
#      Real Excerpt:
#  , had any influence . her mother would talk of her views in the same
# Generated Excerpt:
#  intelligible tone . elizabeth blushed and blushed again with shame and vexation . she could
#
# step 7800 loss 0.12869425117969513
#      Real Excerpt:
#  , and she assured him , with some confusion , of her attachment to mr
# Generated Excerpt:
#  . darcy . “ or , in other words , you are determined to have
#
# step 8000 loss 0.13277123868465424
#      Real Excerpt:
#  and not disturb us with his company . what shall we do with him ?
# Generated Excerpt:
#  lizzy , you must walk out with him again , that he may not be
#
# step 8200 loss 0.12989431619644165
#      Real Excerpt:
#  into the hall , and reached the outward door just in time to receive and
# Generated Excerpt:
#  support her as she entered it . mrs . dashwood , whose terror as they
#
# step 8400 loss 0.1220623254776001
#      Real Excerpt:
#  termination of colonel brandon ' s visit at the park , with his steadiness in
# Generated Excerpt:
#  concealing its cause , filled the mind , and raised the wonder of mrs .
#
# step 8600 loss 0.1331212967634201
#      Real Excerpt:
#  , and may believe how eagerly she would still justify him if she could .
# Generated Excerpt:
#  " he made no answer ; and soon afterwards , by the removal of the
#
# step 8800 loss 0.1253788024187088
#      Real Excerpt:
#  , indeed ! " replied her cousin , with affected earnestness , " and i
# Generated Excerpt:
#  beg you will contradict it , if you ever hear it talked of . "
#
# step 9000 loss 0.13748286664485931
#      Real Excerpt:
#  to him by mrs . dashwood , and he found fresh reason to rejoice in
# Generated Excerpt:
#  what he had done for mr . ferrars , since eventually it promoted the interest
#
# step 9200 loss 0.12871569395065308
#      Real Excerpt:
#  idea of that , for edward ' s sake , frightens away all my inclination
# Generated Excerpt:
#  for hasty measures . " " and for your own sake too , or you
#
# step 9400 loss 0.12916573882102966
#      Real Excerpt:
#  . bennet was firm : it soon led to another ; and mrs . bennet
# Generated Excerpt:
#  found , with amazement and horror , and cried bitterly ; and lucas , who
#
# step 9600 loss 0.11176290363073349
#      Real Excerpt:
#  tomorrow . we must go , for the westons come to us next week you
# Generated Excerpt:
#  know . it was quite a sudden thing our coming at all , and i
#
# step 9800 loss 0.13284872472286224
#      Real Excerpt:
#  and herself especially , there subsisted a very particular regard . they had frequently been
# Generated Excerpt:
#  staying with her in town . the first part of mrs . gardiner ’ s
#
# step 10000 loss 0.11650815606117249
#      Real Excerpt:
#  to listen to . catherine and lydia had information for them of a different sort
# Generated Excerpt:
#  . much had been done , and much had been said in the regiment since
#
# step 10200 loss 0.11722445487976074
#      Real Excerpt:
#  ; and he finally resolved , that it would be absolutely unnecessary , if not
# Generated Excerpt:
#  highly indecorous , to do more for the widow and children of his father ,
#
# step 10400 loss 0.12505045533180237
#      Real Excerpt:
#  the maid to take her place by her sister , she hastened down to the
# Generated Excerpt:
#  drawing - room on mrs . jennings , who still sought the constitutional safeguard of
#
# step 10600 loss 0.1223711371421814
#      Real Excerpt:
#  not be mistaken for one at any other house , elinor felt secure of its
# Generated Excerpt:
#  announcing willoughby ' s approach , and marianne , starting up , moved towards the
#
# step 10800 loss 0.1342426985502243
#      Real Excerpt:
#  tempted , or how am i even to know that it would be wiser to
# Generated Excerpt:
#  resist ? all that i can promise you , therefore , is not to be
#
# step 11000 loss 0.11427635699510574
#      Real Excerpt:
#  the other for intending to do . she will hardly be less hurt , i
# Generated Excerpt:
#  suppose , by robert ' s marrying lucy , than she would have been by
#
# step 11200 loss 0.12122957408428192
#      Real Excerpt:
#  every particular , is more than i can express . " " i am extremely
# Generated Excerpt:
#  glad indeed , if it were , the letter , i am sure has been
#
# step 11400 loss 0.12560604512691498
#      Real Excerpt:
#  still without forfeiting her expectation of the first . " aye , aye , the
# Generated Excerpt:
#  parsonage is but a small one , " said she , after the first ebullition
#
# step 11600 loss 0.11757157742977142
#      Real Excerpt:
#  of his feelings . ” ] chapter xxxviii . [ illustration ] on saturday morning
# Generated Excerpt:
#  elizabeth and mr . collins met for breakfast a few minutes before the others appeared
#
# step 11800 loss 0.14352717995643616
#      Real Excerpt:
#  i shall not go away till you have given me the assurance i require .
# Generated Excerpt:
#  ” “ and i certainly never shall give it . i am not to be
#
# step 12000 loss 0.13627910614013672
#      Real Excerpt:
#  disturb a solitude so reasonable as what she now sought ; and with a mind
# Generated Excerpt:
#  anxiously pre - arranging its result , and a resolution of reviving the subject again
#
# step 12200 loss 0.1264326572418213
#      Real Excerpt:
#  . mr . wickham , after a few moments , touched his hat - -
# Generated Excerpt:
#  a salutation which mr . darcy just deigned to return . what could be the
#
# step 12400 loss 0.1242334321141243
#      Real Excerpt:
#  not to be repelled . i have been a selfish being all my life ,
# Generated Excerpt:
#  in practice , though not in principle . as a child i was taught what
#
# step 12600 loss 0.12070820480585098
#      Real Excerpt:
#  great effect . too much , i am afraid ; for what becomes of the
# Generated Excerpt:
#  moral , if our comfort springs from a breach of promise , for i ought
#
# step 12800 loss 0.1218508780002594
#      Real Excerpt:
#  of what i can assure you to have been perfectly unintentional . i shall never
# Generated Excerpt:
#  reflect on my former acquaintance with what i would endeavour to forget myself , but
#
# step 13000 loss 0.12373461574316025
#      Real Excerpt:
#  s confidence ; and marianne , leaning on elinor ' s arm , was authorised
# Generated Excerpt:
#  to walk by mrs . dashwood , who was now softened again ; for it
#
# step 13200 loss 0.13297389447689056
#      Real Excerpt:
#  did not feel very compassionate . " sometimes , " continued lucy , after wiping
# Generated Excerpt:
#  her eyes , " i think whether it would not be better for us both
#
# step 13400 loss 0.13142047822475433
#      Real Excerpt:
#  before the gentlemen appeared . their powers of conversation were considerable . they could describe
# Generated Excerpt:
#  an entertainment with accuracy , relate an anecdote with humour , and laugh at their
#
# step 13600 loss 0.1203613355755806
#      Real Excerpt:
#  deserving daughters . with what delighted pride she afterwards visited mrs . bingley , and
# Generated Excerpt:
#  talked of mrs . darcy , may be guessed . i wish i could say
#
# step 13800 loss 0.120180644094944
#      Real Excerpt:
#  , could influence a young man so totally independent of everyone . she represented to
# Generated Excerpt:
#  her sister , as forcibly as possible , what she felt on the subject ,
#
# step 14000 loss 0.13265547156333923
#      Real Excerpt:
#  “ i am sure there is not on his . i will answer for it
# Generated Excerpt:
#  , he never cared three straws about her . who could about such a nasty
#
# step 14200 loss 0.12315937876701355
#      Real Excerpt:
#  , because it must be for her loss , for he had nothing but two
# Generated Excerpt:
#  thousand pounds , and no hope of any thing else ; and if he was
#
# step 14400 loss 0.12336384505033493
#      Real Excerpt:
#  of ever being otherwise . she might in time regain tranquillity ; but he ,
# Generated Excerpt:
#  what had he to look forward to ? could he ever be tolerably happy with
#
# step 14600 loss 0.12115002423524857
#      Real Excerpt:
#  . bingley , so easily falls in love with a pretty girl for a few
# Generated Excerpt:
#  weeks , and , when accident separates them , so easily forgets her , that
#
# step 14800 loss 0.13981860876083374
#      Real Excerpt:
#  lady catherine and her daughter , to whom i have related the affair . they
# Generated Excerpt:
#  agree with me in apprehending that this false step in one daughter will be injurious
#
# step 15000 loss 0.12046223878860474
#      Real Excerpt:
#  importance ; and her mother was too happy to be quite so obstinate as usual
# Generated Excerpt:
#  . other schemes , too , came into her head . “ i will go
#
# step 15200 loss 0.12607328593730927
#      Real Excerpt:
#  you . " " to be sure , " continued lucy , after a few
# Generated Excerpt:
#  minutes silence on both sides , " his mother must provide for him sometime or
#
# step 15400 loss 0.11862136423587799
#      Real Excerpt:
#  had been connected , without actually naming her authority , but stating it to be
# Generated Excerpt:
#  such as might be relied on . mrs . gardiner was surprised and concerned :
#
# step 15600 loss 0.13165690004825592
#      Real Excerpt:
#  sigh of repentance ; and rather looked with wonder at her friend , that she
# Generated Excerpt:
#  could have so cheerful an air with such a companion . when mr . collins
#
# step 15800 loss 0.1218196228146553
#      Real Excerpt:
#  whose rectitude and delicacy she was sure her opinion could never be shaken , and
# Generated Excerpt:
#  for whose happiness she grew daily more anxious , as bingley had now been gone
#
# step 16000 loss 0.12792399525642395
#      Real Excerpt:
#  have lived together so long , had not a particular circumstance occurred to give still
# Generated Excerpt:
#  greater eligibility , according to the opinions of mrs . dashwood , to her daughters
#
# step 16200 loss 0.12126552313566208
#      Real Excerpt:
#  . john dashwood now installed herself mistress of norland ; and her mother and sisters
# Generated Excerpt:
#  - in - law were degraded to the condition of visitors . as such ,
#
# step 16400 loss 0.11993768811225891
#      Real Excerpt:
#  , “ informed us that you would certainly not be here till to - morrow
# Generated Excerpt:
#  ; and , indeed , before we left bakewell , we understood that you were
#
# step 16600 loss 0.10982120037078857
#      Real Excerpt:
#  more anxious to know how edward would conduct himself . for him she felt much
# Generated Excerpt:
#  compassion ; - - for lucy very little - - and it cost her some
#
# step 16800 loss 0.12395115941762924
#      Real Excerpt:
#  of raillery as delighted her husband and mother . the idea however started by her
# Generated Excerpt:
#  , was immediately pursued by colonel brandon , who was on every occasion mindful of
#
# step 17000 loss 0.12712281942367554
#      Real Excerpt:
#  set against the match , or violently delighted with it , it was certain that
# Generated Excerpt:
#  her manner would be equally ill adapted to do credit to her sense ; and
#
# step 17200 loss 0.12213364243507385
#      Real Excerpt:
#  allowing her , during your life , one hundred pounds per annum . these are
# Generated Excerpt:
#  conditions which , considering everything , i had no hesitation in complying with , as
#
# step 17400 loss 0.1240251436829567
#      Real Excerpt:
#  four months ! " cried marianne again . " so calm ! so cheerful !
# Generated Excerpt:
#  how have you been supported ? " " by feeling that i was doing my
#
# step 17600 loss 0.12082536518573761
#      Real Excerpt:
#  for it . sense and sensibility has perhaps the fewest out - and - out
# Generated Excerpt:
#  admirers ; but it does not want them . i suppose , however , that
#
# step 17800 loss 0.1327887922525406
#      Real Excerpt:
#  unwilling to go as well from real humanity and good - nature , as from
# Generated Excerpt:
#  a dislike of appearing to be frightened away by his wife , was persuaded at
#
# step 18000 loss 0.10911856591701508
#      Real Excerpt:
#  ” “ to - morrow fortnight . ” “ ay , so it is ,
# Generated Excerpt:
#  ” cried her mother , “ and mrs . long does not come back till
#
# step 18200 loss 0.12394051253795624
#      Real Excerpt:
#  mrs . jennings ' s prophecies , though rather jumbled together , were chiefly fulfilled
# Generated Excerpt:
#  ; for she was able to visit edward and his wife in their parsonage by
#
# step 18400 loss 0.11115186661481857
#      Real Excerpt:
#  a very awkward moment ; and the countenance of each showed that it was so
# Generated Excerpt:
#  . they all looked exceedingly foolish ; and edward seemed to have as great an
#
# step 18600 loss 0.12382374703884125
#      Real Excerpt:
#  parted for ever on the spot , would he consent to it ; but he
# Generated Excerpt:
#  said it should never be , he did not regard his mother ' s anger
#
# step 18800 loss 0.1263289749622345
#      Real Excerpt:
#  illustration : mischievous tricks . ] " and here is my sweet little annamaria ,
# Generated Excerpt:
#  " she added , tenderly caressing a little girl of three years old , who
#
# step 19000 loss 0.12144127488136292
#      Real Excerpt:
#  what is your success ? ” she shook her head . “ i do not
# Generated Excerpt:
#  get on at all the work of her misery . i do not ask above
#
# step 19200 loss 0.12402938306331635
#      Real Excerpt:
#  internal revenue service . the foundation ’ s ein or federal tax identification number is
# Generated Excerpt:
#  64 - 6221541 . contributions to the project gutenberg literary archive foundation are tax deductible
#
# step 19400 loss 0.11595535278320312
#      Real Excerpt:
#  her ( for my father lived only a few months after their marriage , and
# Generated Excerpt:
#  i was with my regiment in the east indies ) she should fall ? had
#
# step 19600 loss 0.11578143388032913
#      Real Excerpt:
#  what i have suffered for edward ' s sake these last four years . every
# Generated Excerpt:
#  thing in such suspense and uncertainty ; and seeing him so seldom - - we
#
# step 19800 loss 0.11596959829330444
#      Real Excerpt:
#  she prevent her from following him herself ; and to persuade her to check her
# Generated Excerpt:
#  agitation , to wait , at least , with the appearance of composure , till
#
# step 20000 loss 0.10858333110809326
#      Real Excerpt:
#  being really beloved by edward , it required no other consideration of probabilities to make
# Generated Excerpt:
#  it natural that lucy should be jealous ; and that she was so , her
#
# step 20200 loss 0.11942248046398163
#      Real Excerpt:
#  hurry off his servant with a message to mr . harris , and an order
# Generated Excerpt:
#  for post - horses directly , she wrote a few lines to her mother .
#
# step 20400 loss 0.12647899985313416
#      Real Excerpt:
#  and i spoke to him twice myself without receiving an answer . could there be
# Generated Excerpt:
#  finer symptoms ? is not general incivility the very essence of love ? ” “
#
# step 20600 loss 0.12717565894126892
#      Real Excerpt:
#  bennet , he offered himself as his antagonist at backgammon . mr . bennet accepted
# Generated Excerpt:
#  the challenge , observing that he acted very wisely in leaving kent without remembering that
#
# step 20800 loss 0.12091078609228134
#      Real Excerpt:
#  willingly without pemberley as with it , and anybody who can read between lines will
# Generated Excerpt:
#  not find the lovers ’ conversations in the final chapters so frigid as they might
#
# step 21000 loss 0.12671153247356415
#      Real Excerpt:
#  sake , could not press the subject farther , and she hoped it was not
# Generated Excerpt:
#  required of her for willoughby ' s ; since , though marianne might lose much
#
# step 21200 loss 0.13266023993492126
#      Real Excerpt:
#  farewell , the more gentle adieus of her sisters were uttered without being heard .
# Generated Excerpt:
#  [ illustration : the arrival of the gardiners ] chapter xlii . [ illustration ]
#
# step 21400 loss 0.11660346388816833
#      Real Excerpt:
#  but i would not alarm you too much . donavan says there is nothing materially
# Generated Excerpt:
#  to be apprehended ; her constitution is a good one , and her resolution equal
#
# step 21600 loss 0.11565349996089935
#      Real Excerpt:
#  time mr . bingley ’ s name was scarcely ever mentioned between them . mrs
# Generated Excerpt:
#  . bennet still continued to wonder and repine at his returning no more ; and
#
# step 21800 loss 0.11846715211868286
#      Real Excerpt:
#  . ferrars ' s way of treating me yesterday ? so exceeding affable as she
# Generated Excerpt:
#  was ! you know how i dreaded the thoughts of seeing her ; but the
#
# step 22000 loss 0.12321020662784576
#      Real Excerpt:
#  entrance of jane and elizabeth . “ ay , there she comes , ” continued
# Generated Excerpt:
#  mrs . bennet , “ looking as unconcerned as may be , and caring no
#
# step 22200 loss 0.1264774203300476
#      Real Excerpt:
#  you would not have been a bit tired : and to say the truth it
# Generated Excerpt:
#  was not very pretty of him not to give you the meeting when he was
#
# step 22400 loss 0.11725910753011703
#      Real Excerpt:
#  the whole family in short were properly overjoyed on the occasion . the younger girls
# Generated Excerpt:
#  formed hopes of coming out a year or two sooner than they might otherwise have
#
# step 22600 loss 0.11824124306440353
#      Real Excerpt:
#  notice of this ; and directing her attention to their visitor , endeavoured to support
# Generated Excerpt:
#  something like discourse with him , by talking of their present residence , its conveniences
#
# step 22800 loss 0.1252783089876175
#      Real Excerpt:
#  , indeed it is ! " and seemed almost ready to throw herself into his
# Generated Excerpt:
#  arms , when colonel brandon appeared . it was too great a shock to be
#
# step 23000 loss 0.11584777384996414
#      Real Excerpt:
#  herself . " remember , elinor , " said she , " how very often
# Generated Excerpt:
#  sir john fetches our letters himself from the post , and carries them to it
#
# step 23200 loss 0.12175849825143814
#      Real Excerpt:
#  . he was very fond of them . ” this accounted to elizabeth for mr
# Generated Excerpt:
#  . wickham ’ s being among them . mrs . reynolds then directed their attention
#
# step 23400 loss 0.12737414240837097
#      Real Excerpt:
#  a letter that morning received from mrs . jennings declared her danger most imminent -
# Generated Excerpt:
#  - the palmers are all gone off in a fright , & c . i
#
# step 23600 loss 0.11983049660921097
#      Real Excerpt:
#  with no other view . " " there now , " - - said his
# Generated Excerpt:
#  lady , " you see mr . palmer expects you ; so you cannot refuse
#
# step 23800 loss 0.12017439305782318
#      Real Excerpt:
#  my family , and blessed above them all ? if i could but see you
# Generated Excerpt:
#  as happy ! if there were but such another man for you ! it is
#
# step 24000 loss 0.12478016316890717
#      Real Excerpt:
#  astonishment , " if it could be of any use to you to know my
# Generated Excerpt:
#  opinion of her . but really i never understood that you were at all connected
#
# step 24200 loss 0.1197519302368164
#      Real Excerpt:
#  of his letter , with the perfect unconcern with which her praises were received ,
# Generated Excerpt:
#  formed a curious dialogue , and was exactly in unison with her opinion of each
#
# step 24400 loss 0.12879084050655365
#      Real Excerpt:
#  . “ he meant , i believe , ” replied jane , “ to go
# Generated Excerpt:
#  to epsom , the place where they last changed horses , see the postilions ,
#
# step 24600 loss 0.12766073644161224
#      Real Excerpt:
#  where jane , who came running downstairs from her mother ’ s apartment , immediately
# Generated Excerpt:
#  met her . elizabeth , as she affectionately embraced her , whilst tears filled the
#
# step 24800 loss 0.11599986255168915
#      Real Excerpt:
#  t hurt your eyes : - - will you ring the bell for some working
# Generated Excerpt:
#  candles ? my poor little girl would be sadly disappointed , i know , if
#
# step 25000 loss 0.11625228077173233
#      Real Excerpt:
#  " but mrs . john dashwood would not much approve of edward ' s going
# Generated Excerpt:
#  into orders . " " then i rather suspect that my interest would do very

# %%
plt.plot(losses)

# %%
print(d_model, block_size, n_blocks, n_heads, len(vocab), step)
# Out:
# 64 128 4 4 9378 25000

# %%
## Save model to reload later
model_5p6Mparams = {
    "model_state": model.state_dict(),
    "opt_state": opt.state_dict(),
    "step": 100_000,
    "config": dict(
        vocab_size=len(vocab),
        block_size=block_size,
        d_model=256,
        n_blocks=n_blocks,
        n_heads=n_heads,
        d_ff=1024,
    ),
}
torch.save(model_5p6Mparams, "miniGPT_5p6Mparams.pt")

# %% [markdown]
# # Attention Heatmap

# %%
# Take one excerpt, idx 
model.eval()
idx, _ = get_batch(ids, batch_size=100, block_size=128) 
with torch.no_grad():
    _, attn_maps = model(idx, return_attn=True)

# Define #batches (1), token length (T), #blocks, and #heads 
B, T = idx.shape
n_blocks = len(attn_maps)
n_heads =  attn_maps[0].shape[1]
print("TEXT:\n", " ".join(itos[i] for i in idx[0].tolist()))
print(n_blocks, n_heads, np.shape(attn_maps))
# Out:
# TEXT:
#  , whose negative might be uttered in such a manner as must be decisive , and whose behaviour at least could not be mistaken for the affectation and coquetry of an elegant female . [ illustration ] chapter xx . [ illustration ] mr . collins was not left long to the silent contemplation of his successful love ; for mrs . bennet , having dawdled about in the vestibule to watch for the end of the conference , no sooner saw elizabeth open the door and with quick step pass her towards the staircase , than she entered the breakfast - room , and congratulated both him and herself in warm terms on the happy prospect of their nearer connection . mr . collins received and returned
# 4 4 (4, 100, 4, 128, 128)

# %%
# Try to make a repeated random sequence ... 
L = 16
base, _ = get_batch(ids, batch_size=1000, block_size=L)
idx = torch.cat([base, base, base, base], dim=1)
with torch.no_grad():
    _, attn_maps = model(idx, return_attn=True)

# Define #batches (1), token length (T), #blocks, and #heads 
B, T = idx.shape
n_blocks = len(attn_maps)
n_heads =  attn_maps[0].shape[1]
print("TEXT:\n", " ".join(itos[i] for i in idx[0].tolist()))
# Out:
# TEXT:
#  , would be hastening to the same vexatious conclusion . at that instant she felt , , would be hastening to the same vexatious conclusion . at that instant she felt , , would be hastening to the same vexatious conclusion . at that instant she felt , , would be hastening to the same vexatious conclusion . at that instant she felt ,

# %%
# Repeat vs control, then you'll plot Δ = (repeat - control) later
L = 16
base, _ = get_batch(ids, batch_size=1500, block_size=L)

idx_rep = torch.cat([base, base, base, base], dim=1)
# idx_rep = torch.cat([base], dim=1)
rand1, _ = get_batch(ids, batch_size=1500, block_size=L)
rand2, _ = get_batch(ids, batch_size=1500, block_size=L)
rand3, _ = get_batch(ids, batch_size=1500, block_size=L)
rand4, _ = get_batch(ids, batch_size=1500, block_size=L)
idx_ctl = torch.cat([base, rand2, rand3, rand4], dim=1)
# idx_ctl = torch.cat([rand1], dim=1)

with torch.no_grad():
    _, attn_rep = model(idx_rep, return_attn=True)
    _, attn_ctl = model(idx_ctl, return_attn=True)

B, T = idx_rep.shape
n_blocks = len(attn_rep)
n_heads  = attn_rep[0].shape[1]
print("TEXT (repeat):\n", " ".join(itos[i] for i in idx_rep[0].tolist()))
print("TEXT (repeat):\n", " ".join(itos[i] for i in idx_ctl[0].tolist()))
# Out:
# TEXT (repeat):
#  , with triumph . this person ' s suspicions , therefore , i have had to , with triumph . this person ' s suspicions , therefore , i have had to , with triumph . this person ' s suspicions , therefore , i have had to , with triumph . this person ' s suspicions , therefore , i have had to
# TEXT (repeat):
#  , with triumph . this person ' s suspicions , therefore , i have had to use of and all access to other copies of project gutenberg ™ works . • you , i can tell you ; exactly what i call a nice old fashioned place , in the vestibule to watch for the end of the conference , no sooner saw elizabeth

# %%
## Plot Heatmap
def diag_means(M, max_off=5):
    out = {}
    for off in range(-max_off, max_off+1):
        d = np.diagonal(M, offset=off)
        if len(d): out[off] = d.mean()
    return out
from matplotlib.colors import LogNorm
fig, axes = plt.subplots(n_blocks, n_heads, figsize=(2*n_heads, 2*n_blocks))
for b in range(n_blocks): 
    # A = attn_maps[b].mean(dim=0).detach().cpu().numpy() # take the first batch B ( shape = (n,T,T) ) 
    A_rep = attn_rep[b].mean(dim=0).detach().cpu().numpy()   # (H,T,T)
    A_ctl = attn_ctl[b].mean(dim=0).detach().cpu().numpy()
    A = A_rep - A_ctl     
    for h in range(n_heads):
        L = 16; k = 1;
        M = A[h, k*L:(k+1)*L, (k-1)*L:k*L]
        ####################################
        Mraw = attn_rep[b].mean(0)[h, k*L:(k+1)*L, (k-1)*L:k*L].cpu().numpy()
        if b==1: print(diag_means(Mraw, max_off=3))   # induction head should peak at off=+1

        if b==1: print("Δ on copy diag:",     np.diagonal(A[h], offset=-L).mean())
        if b==1: print("Δ on induction diag:",np.diagonal(A[h], offset=-(L-1)).mean())
        ########################################
        ax = axes[b, h] 
        # M = M / (M.sum(axis=1, keepdims=True) + 1e-9)
        # M = M - M.mean(axis=1, keepdims=True)
        # M = (A_rep - A_ctl)[h, k*L:(k+1)*L, (k-1)*L:k*L]
        v = np.max(np.abs(M))
        # v = np.percentile(np.abs(A[h]), 99) 
        ax.imshow(A[h][L:4*L, L:4*L],  cmap="viridis", vmin=-v, vmax=v, aspect="auto", origin="upper")
        # ax.imshow(M,  cmap="viridis", vmin=-v, vmax=v, aspect="auto", origin="upper")
        ax.set_title(f"Block {b}, Head {h}")
        ax.set_xticks([]); ax.set_yticks([])
        d0  = np.diagonal(M,  0).mean()   # copy
        dm1 = np.diagonal(M, -1).mean()   # induction (t -> t-1)
        dp1 = np.diagonal(M, +1).mean()   # anti-induction (t -> t+1) 
        # print("copy", d0, "ind(-1)", dm1, "ind(+1)", dp1, "best", max(dm1,dp1)-d0)
plt.tight_layout()
plt.show()
# print the actual tokens / text for the prompt you're plotting
print("TEXT:\n", " ".join(itos[i] for i in idx[0].tolist()))
# Out:
# {-3: 0.036363482, -2: 0.03812148, -1: 0.043959863, 0: 0.0431488, 1: 0.044785973, 2: 0.042917397, 3: 0.04804171}
# Δ on copy diag: 0.00049202295
# Δ on induction diag: -1.0464435e-05
# {-3: 0.03386636, -2: 0.03820484, -1: 0.03810871, 0: 0.045533296, 1: 0.04426581, 2: 0.04407572, 3: 0.04722001}
# Δ on copy diag: 0.00027679946
# Δ on induction diag: -0.00018132983
# {-3: 0.03978694, -2: 0.03964707, -1: 0.04319819, 0: 0.044395335, 1: 0.043516763, 2: 0.04526629, 3: 0.043975607}
# Δ on copy diag: 0.00012252253
# Δ on induction diag: 1.1203753e-05
# {-3: 0.038598076, -2: 0.040191222, -1: 0.038752835, 0: 0.04376929, 1: 0.044429265, 2: 0.04327812, 3: 0.04408651}
# Δ on copy diag: 0.0006245331
# Δ on induction diag: -5.612036e-05
# TEXT:
#  , would be hastening to the same vexatious conclusion . at that instant she felt , , would be hastening to the same vexatious conclusion . at that instant she felt , , would be hastening to the same vexatious conclusion . at that instant she felt , , would be hastening to the same vexatious conclusion . at that instant she felt ,

# %%
## Plot Heatmap
def diag_means(M, max_off=5):
    out = {}
    for off in range(-max_off, max_off+1):
        d = np.diagonal(M, offset=off)
        if len(d): out[off] = d.mean()
    return out
from matplotlib.colors import LogNorm
fig, axes = plt.subplots(n_blocks, n_heads, figsize=(2*n_heads, 2*n_blocks))
for b in range(n_blocks): 
    # A = attn_maps[b].mean(dim=0).detach().cpu().numpy() # take the first batch B ( shape = (n,T,T) ) 
    A_rep = attn_rep[b].mean(dim=0).detach().cpu().numpy()   # (H,T,T)
    A_ctl = attn_ctl[b].mean(dim=0).detach().cpu().numpy()
    A = A_rep - A_ctl     
    for h in range(n_heads):
        L = 16; k = 1;
        M = A[h, k*L:(k+1)*L, (k-1)*L:k*L]
        ####################################
        Mraw = attn_rep[b].mean(0)[h, k*L:(k+1)*L, (k-1)*L:k*L].cpu().numpy()
        if b==1: print(diag_means(Mraw, max_off=3))   # induction head should peak at off=+1

        if b==1: print("Δ on copy diag:",     np.diagonal(A[h], offset=-L).mean())
        if b==1: print("Δ on induction diag:",np.diagonal(A[h], offset=-(L-1)).mean())
        ########################################
        ax = axes[b, h] 
        # M = M / (M.sum(axis=1, keepdims=True) + 1e-9)
        # M = M - M.mean(axis=1, keepdims=True)
        # M = (A_rep - A_ctl)[h, k*L:(k+1)*L, (k-1)*L:k*L]
        # v = np.max(np.abs(M))
        v = np.percentile(np.abs(A[h]), 99) 
        ax.imshow(A[h][L:4*L, L:4*L],  cmap="viridis", vmin=-v, vmax=v, aspect="auto", origin="upper")
        ax.set_title(f"Block {b}, Head {h}")
        ax.set_xticks([]); ax.set_yticks([])
        d0  = np.diagonal(M,  0).mean()   # copy
        dm1 = np.diagonal(M, -1).mean()   # induction (t -> t-1)
        dp1 = np.diagonal(M, +1).mean()   # anti-induction (t -> t+1) 
        # print("copy", d0, "ind(-1)", dm1, "ind(+1)", dp1, "best", max(dm1,dp1)-d0)
plt.tight_layout()
plt.show()
# print the actual tokens / text for the prompt you're plotting
print("TEXT:\n", " ".join(itos[i] for i in idx[0].tolist()))
# Out:
# {-3: 0.0054427152, -2: 0.006770968, -1: 0.008611276, 0: 0.0046188617, 1: 0.01348708, 2: 0.014976606, 3: 0.01718222}
# Δ on copy diag: -0.006997678
# Δ on induction diag: 0.0019066839
# {-3: 0.008051265, -2: 0.009113303, -1: 0.0116888415, 0: 0.0077411085, 1: 0.02199142, 2: 0.019776428, 3: 0.023495257}
# Δ on copy diag: -0.008879776
# Δ on induction diag: 0.005503926
# {-3: 0.0063750274, -2: 0.0077025606, -1: 0.009255495, 0: 0.0056230067, 1: 0.017019622, 2: 0.017983412, 3: 0.02041964}
# Δ on copy diag: -0.009229603
# Δ on induction diag: 0.0020950509
# {-3: 0.0061967405, -2: 0.0075484845, -1: 0.010852113, 0: 0.0058859205, 1: 0.016721725, 2: 0.017311579, 3: 0.019811532}
# Δ on copy diag: -0.00815678
# Δ on induction diag: 0.0026453368
# TEXT:
#  seemed too awful a moment for speech . [ illustration : " you have heard , seemed too awful a moment for speech . [ illustration : " you have heard , seemed too awful a moment for speech . [ illustration : " you have heard , seemed too awful a moment for speech . [ illustration : " you have heard ,

# %% [markdown]
# # Head Ablations

# %%
# Make repeat, control batches to test on
B = 128
L = 64
print(vocab_size)

x = torch.randint(0, len(vocab), (B, L))
y = torch.randint(0, len(vocab), (B, L))

idx_rep = torch.cat([x, x], dim=1)   # repeat  ... [B, 2L]
idx_ctl = torch.cat([x, y], dim=1)   # control ... [B, 2L]
# Out:
# 10000

# %%
# model = TinyGPT(vocab_size=len(vocab), block_size=block_size, 
#                 d_model=200, n_blocks=4, n_heads=4, d_ff=800).to(device)

# %%
##### RECREATE MODEL INSTANCE ########

model2 = TinyGPT(vocab_size=len(vocab), block_size=block_size, d_model=200, n_blocks=4, n_heads=4, d_ff=800).to(device)
model2.load_state_dict(model.state_dict())   # copy weights from old model
model2.eval()

######################################
# Out:
# TinyGPT(
#   (tok_emb): Embedding(9378, 200)
#   (pos_emb): Embedding(128, 200)
#   (blocks): ModuleList(
#     (0-3): 4 x Block(
#       (ln1): LayerNorm((200,), eps=1e-05, elementwise_affine=True)
#       (attn): CausalSelfAttention(
#         (qkv): Linear(in_features=200, out_features=600, bias=False)
#         (proj): Linear(in_features=200, out_features=200, bias=False)
#       )
#       (ln2): LayerNorm((200,), eps=1e-05, elementwise_affine=True)
#       (mlp): Sequential(
#         (0): Linear(in_features=200, out_features=800, bias=True)
#         (1): GELU(approximate='none')
#         (2): Linear(in_features=800, out_features=200, bias=True)
#       )
#     )
#   )
#   (ln_f): LayerNorm((200,), eps=1e-05, elementwise_affine=True)
#   (lm_head): Linear(in_features=200, out_features=9378, bias=False)
# )

# %%
@torch.no_grad()
def second_half_loss(model, idx, ablate=None):
    # idx: [B, 2L]
    logits = model(idx, return_attn=False, ablate=ablate)  # you add ablate support
    targets = idx[:, 1:]           # [B, 2L-1]
    logits  = logits[:, :-1, :]    # [B, 2L-1, V]

    L = idx.shape[1] // 2
    mask = torch.zeros_like(targets, dtype=torch.bool)
    mask[:, L-1:2*L-1] = True      # targets for tokens at positions L..2L-1

    return F.cross_entropy(logits[mask], targets[mask]).item()

base_rep = second_half_loss(model2, idx_rep)
base_ctl = second_half_loss(model2, idx_ctl)
base_gap = base_ctl - base_rep   # “how much better than random” on repeats
print(base_rep, base_ctl, base_gap)
# Out:
# 135.29200744628906 135.51773071289062 0.2257232666015625

# %%
with torch.no_grad():
    logits = model2(idx_rep)
    targets = idx_rep[:,1:]
    logits  = logits[:,:-1,:]
    L = idx_rep.shape[1]//2
    mask = torch.zeros_like(targets, dtype=torch.bool)
    mask[:, L-1:2*L-1] = True
    print("num positions:", mask.sum().item())

    loss = F.cross_entropy(logits[mask], targets[mask], reduction="mean")
    print("mean CE:", loss.item())
# Out:
# num positions: 16000
# mean CE: 134.50750732421875
